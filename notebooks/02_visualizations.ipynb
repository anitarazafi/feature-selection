# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
from src.analysis.results_table import build_results_table
report, best, pivot_auc, pivot_f1 = build_results_table(ds)
# Out:
# Saved full table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/all_results.csv
# Saved best-per-method table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/best_per_method.csv
# Saved AUC pivot to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/pivot_auc.csv
# Saved F1 pivot  to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/pivot_f1.csv
#
# ============================================================
# AUC SUMMARY (best per method per model)
# ============================================================
# model                      mlp  random_forest  xgboost
# fs_method
# baseline                0.9089         0.9299   0.9547
# chi2                    0.9243         0.9324   0.9561
# differential_evolution  0.9176         0.9745   0.9621
# lime                    0.9256         0.9470   0.9534
# mutual_information      0.9306         0.9706   0.9589
# pso                     0.9021         0.9700   0.9615
# rfe                     0.9256         0.9706   0.9590
# shap                    0.9392         0.9768   0.9576
#
# ============================================================
# F1 SUMMARY (best per method per model)
# ============================================================
# model                      mlp  random_forest  xgboost
# fs_method
# baseline                0.5196         0.1866   0.5873
# chi2                    0.5571         0.2703   0.5830
# differential_evolution  0.5453         0.6378   0.6109
# lime                    0.6104         0.2975   0.5519
# mutual_information      0.5610         0.6051   0.6110
# pso                     0.5208         0.5944   0.6183
# rfe                     0.5524         0.5971   0.6151
# shap                    0.6077         0.6342   0.6053
#
# ============================================================
# BEST METHOD PER MODEL (by AUC)
# ============================================================
#   mlp                  → shap                      AUC=0.9392  F1=0.6077  k=10
#   random_forest        → shap                      AUC=0.9768  F1=0.6342  k=10
#   xgboost              → differential_evolution    AUC=0.9621  F1=0.6109  k=10
#
# ============================================================
# IMPROVEMENT OVER BASELINE (AUC)
# ============================================================
#   mlp                  → best: shap                      Δ AUC=+0.0303
#   random_forest        → best: shap                      Δ AUC=+0.0469
#   xgboost              → best: differential_evolution    Δ AUC=+0.0074

# %%
from src.visualization.plots import plot_auc_curves
plot_auc_curves(ds)
# Out:
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/auc_vs_features.png
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/auc_per_method.png
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/f1_vs_features.png

# %%
from src.visualization.plots import plot_heatmap
plot_heatmap(ds)
# Out:
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/heatmap.png

# %%
from src.visualization.plots import plot_roc_curves
plot_roc_curves(ds)
# Out:
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/roc_curves.png

# %%
from src.visualization.plots import plot_feature_overlap
plot_feature_overlap(ds)
# Out:
# ── k=10 ──────────────────────────────────
#   Missing: differential_evolution_k10_features.json
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/feature_overlap_k10.png
#   Consensus features (all 6 methods): []
#   Majority features  (≥50% methods):              ['BASIN_EP', 'LAT', 'USA_LON', 'BASIN_WP', 'BASIN_SI', 'LON', 'BASIN_NI']
#
# ── k=30 ──────────────────────────────────
#   Missing: differential_evolution_k30_features.json
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/feature_overlap_k30.png
#   Consensus features (all 6 methods): ['LAT', 'BASIN_NI', 'LON']
#   Majority features  (≥50% methods):              ['USA_AGENCY_nan', 'NATURE_TS', 'USA_AGENCY_jtwc_wp', 'BASIN_SI', 'WMO_AGENCY_bom', 'BASIN_nan', 'WMO_AGENCY_newdelhi', 'USA_SSHS', 'USA_WIND', 'BASIN_WP', 'WMO_AGENCY_hurdat_epa', 'USA_LAT', 'USA_STATUS_TD', 'BASIN_EP', 'USA_AGENCY_hurdat_epa', 'USA_STATUS_nan', 'USA_AGENCY_jtwc_io', 'USA_LON', 'NATURE_NR', 'BASIN_SP', 'WMO_AGENCY_atcf', 'USA_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'USA_PRES', 'USA_STATUS_SD', 'USA_AGENCY_jtwc_ep', 'WMO_PRES', 'NATURE_ET', 'STORM_DIR', 'NUMBER', 'STORM_SPEED']
#
# ── k=50 ──────────────────────────────────
#   Missing: differential_evolution_k50_features.json
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/feature_overlap_k50.png
#   Consensus features (all 6 methods): ['WMO_AGENCY_nadi', 'WMO_AGENCY_hurdat_atl', 'USA_STATUS_DB', 'NATURE_DS', 'BASIN_nan', 'USA_SSHS', 'LAT', 'BASIN_NI', 'WMO_AGENCY_hurdat_epa', 'USA_STATUS_HU', 'NATURE_ET', 'STORM_DIR', 'USA_PRES', 'BASIN_EP', 'USA_AGENCY_hurdat_epa', 'NATURE_SS', 'NATURE_MX', 'USA_AGENCY_hurdat_atl', 'WMO_AGENCY_reunion', 'LON']
#   Majority features  (≥50% methods):              ['USA_AGENCY_nan', 'NATURE_TS', 'USA_AGENCY_jtwc_wp', 'WMO_AGENCY_tokyo', 'BASIN_SI', 'WMO_AGENCY_bom', 'TRACK_TYPE_main', 'WMO_AGENCY_newdelhi', 'USA_WIND', 'BASIN_WP', 'USA_STATUS_EX', 'USA_LAT', 'USA_STATUS_TD', 'SEASON', 'WMO_AGENCY_nan', 'USA_AGENCY_jtwc_sh', 'USA_STATUS_TS', 'USA_STATUS_TY', 'USA_STATUS_SD', 'USA_STATUS_XX', 'NUMBER', 'USA_STATUS_nan', 'WMO_AGENCY_wellington', 'USA_STATUS_LO', 'TRACK_TYPE_nan', 'USA_AGENCY_jtwc_io', 'USA_LON', 'WMO_PRES', 'NATURE_NR', 'BASIN_SP', 'WMO_AGENCY_atcf', 'USA_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'USA_STATUS_SS', 'BASIN_SA', 'USA_AGENCY_cphc', 'USA_STATUS_ST', 'USA_AGENCY_jtwc_ep', 'STORM_SPEED']
