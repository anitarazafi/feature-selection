# %%
from src.experiments.sweep_k import sweep_k
from src.experiments.run_baseline import train_baseline
from src.experiments.run_traditional_fs import run_traditional_fs
from src.experiments.run_optimization_fs import run_optimization_fs
from src.experiments.run_xai_fs import run_xai_fs

# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
results = sweep_k(ds)
# Out:
# ============================================================
#  Validation Sweep: Choosing optimal k for ibtracs.ALL.list.v04r01
# ============================================================
# Total features: 63
# k values to sweep: [3, 5, 7, 10, 13, 15, 18, 20, 25, 30, 35, 40, 45, 50, 55, 60, 63]
#
# Computing Mutual Information scores...
# MI computation time: 30.47s
#   k=  3 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.8616  Val F1=0.0709  (0.3s)
#   k=  5 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.8958  Val F1=0.2866  (0.2s)
#   k=  7 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9838  Val F1=0.7656  (0.3s)
#   k= 10 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9833  Val F1=0.7607  (0.3s)
#   k= 13 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9837  Val F1=0.7640  (0.3s)
#   k= 15 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9827  Val F1=0.7413  (0.3s)
#   k= 18 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9835  Val F1=0.7536  (0.3s)
#   k= 20 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9826  Val F1=0.7453  (0.3s)
#   k= 25 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9828  Val F1=0.7544  (0.4s)
#   k= 30 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9815  Val F1=0.7485  (0.4s)
#   k= 35 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9816  Val F1=0.7505  (0.4s)
#   k= 40 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9814  Val F1=0.7385  (0.6s)
#   k= 45 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9802  Val F1=0.7314  (0.5s)
#   k= 50 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9794  Val F1=0.7317  (0.6s)
#   k= 55 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9797  Val F1=0.7407  (0.6s)
#   k= 60 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9795  Val F1=0.7473  (0.7s)
#   k= 63 ...
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [03:48:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Val AUC=0.9795  Val F1=0.7473  (0.6s)
#
# Saved sweep results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/k_sweep.csv
# Saved plot to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/k_sweep.png
#
# ────────────────────────────────────────
# Best k by Val AUC: k=7  (AUC=0.9838)
# Best k by Val F1:  k=7  (F1=0.7656)
# ────────────────────────────────────────

# %%
results = train_baseline(ds)
# Out:
# ============================================================
# =Training baseline models for: ibtracs.ALL.list.v04r01
# Training samples:   213577
# Validation samples: 30511
# Test samples:       61022
# Features: 63
#
# Training random_forest...
#   Training time: 2.46s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9266   0.9073
#   precision      0.8371   0.8878
#   recall         0.1069   0.1043
#   f1_score       0.1896   0.1866
#   auc            0.9390   0.9299
#
# Training xgboost...
#   Training time: 0.99s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9480   0.9366
#   precision      0.8473   0.8740
#   recall         0.4300   0.4422
#   f1_score       0.5705   0.5873
#   auc            0.9633   0.9547
#
# Training mlp...
#   Training time: 12.07s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9427   0.9276
#   precision      0.7807   0.8044
#   recall         0.3994   0.3838
#   f1_score       0.5285   0.5196
#   auc            0.9288   0.9089
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/baseline.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/baseline
#
# Saved LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/baseline.tex
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/learning_curves.png

# %%
results = run_traditional_fs(ds)
# Out:
# ============================================================
# = Running Traditional Feature Selection for: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples:    213577
# Validation samples:  30511
# Test samples:        61022
# Features (original): 63
# k (features to select): 7
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=7)
# ────────────────────────────────────────────────────────────
# Selected features (7): ['LAT', 'LON', 'USA_LON', 'BASIN_EP', 'WMO_AGENCY_nan', 'USA_AGENCY_nan', 'USA_STATUS_nan']
# Feature selection time: 30.49s
#
#   Training random_forest...
#     Training time: 1.62s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9436   0.9330
#     precision      0.8558   0.8842
#     recall         0.3582   0.3950
#     f1_score       0.5050   0.5461
#     auc            0.9683   0.9615
#
#   Training xgboost...
#     Training time: 0.51s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9473   0.9352
#     precision      0.8624   0.8720
#     recall         0.4092   0.4278
#     f1_score       0.5551   0.5740
#     auc            0.9621   0.9528
#
#   Training mlp...
#     Training time: 7.42s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9402   0.9213
#     precision      0.7905   0.7786
#     recall         0.3480   0.3198
#     f1_score       0.4833   0.4534
#     auc            0.9214   0.9112
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI-SQUARE (k=7)
# ────────────────────────────────────────────────────────────
# Selected features (7): ['BASIN_EP', 'BASIN_NI', 'WMO_AGENCY_bom', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_newdelhi', 'WMO_AGENCY_wellington', 'USA_AGENCY_hurdat_epa']
# Feature selection time: 0.11s
#
#   Training random_forest...
#     Training time: 0.45s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9197   0.8980
#     precision      0.0000   0.0000
#     recall         0.0000   0.0000
#     f1_score       0.0000   0.0000
#     auc            0.6641   0.6278
#
#   Training xgboost...
#     Training time: 0.36s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9197   0.8980
#     precision      0.0000   0.0000
#     recall         0.0000   0.0000
#     f1_score       0.0000   0.0000
#     auc            0.6646   0.6278
#
#   Training mlp...
#     Training time: 2.30s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9197   0.8980
#     precision      0.0000   0.0000
#     recall         0.0000   0.0000
#     f1_score       0.0000   0.0000
#     auc            0.6636   0.6272
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=7, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features (7): ['NUMBER', 'LAT', 'LON', 'USA_LAT', 'USA_LON', 'USA_SSHS', 'BASIN_NI']
# Feature selection time: 26.04s
#
#   Training random_forest...
#     Training time: 1.70s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9455   0.9373
#     precision      0.8683   0.8909
#     recall         0.3794   0.4395
#     f1_score       0.5281   0.5886
#     auc            0.9741   0.9715
#
#   Training xgboost...
#     Training time: 0.40s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9489   0.9376
#     precision      0.8669   0.8700
#     recall         0.4304   0.4570
#     f1_score       0.5752   0.5993
#     auc            0.9645   0.9579
#
#   Training mlp...
#     Training time: 7.26s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9433   0.9289
#     precision      0.8034   0.8138
#     recall         0.3900   0.3933
#     f1_score       0.5251   0.5303
#     auc            0.9279   0.9237
#
#
# ────────────────────────────────────────────────────────────
# Constructing FS-Set (Union of Traditional Methods)
# ────────────────────────────────────────────────────────────
# Individual method contributions:
#   mutual_information: ['BASIN_EP', 'LAT', 'LON', 'USA_AGENCY_nan', 'USA_LON', 'USA_STATUS_nan', 'WMO_AGENCY_nan']
#   chi2: ['BASIN_EP', 'BASIN_NI', 'USA_AGENCY_hurdat_epa', 'WMO_AGENCY_bom', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_newdelhi', 'WMO_AGENCY_wellington']
#   rfe: ['BASIN_NI', 'LAT', 'LON', 'NUMBER', 'USA_LAT', 'USA_LON', 'USA_SSHS']
#
# FS-Set (union): ['BASIN_EP', 'BASIN_NI', 'LAT', 'LON', 'NUMBER', 'USA_AGENCY_hurdat_epa', 'USA_AGENCY_nan', 'USA_LAT', 'USA_LON', 'USA_SSHS', 'USA_STATUS_nan', 'WMO_AGENCY_bom', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_nan', 'WMO_AGENCY_newdelhi', 'WMO_AGENCY_wellington']
# FS-Set size: 16
#
#   Training random_forest...
#     Training time: 1.81s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9434   0.9327
#     precision      0.8509   0.8855
#     recall         0.3586   0.3913
#     f1_score       0.5046   0.5428
#     auc            0.9674   0.9622
#
#   Training xgboost...
#     Training time: 0.47s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9482   0.9367
#     precision      0.8574   0.8683
#     recall         0.4268   0.4469
#     f1_score       0.5699   0.5901
#     auc            0.9629   0.9563
#
#   Training mlp...
#     Training time: 6.36s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9423   0.9244
#     precision      0.7524   0.7628
#     recall         0.4190   0.3751
#     f1_score       0.5383   0.5029
#     auc            0.9213   0.9179
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/traditional.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/traditional
# Saved LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/traditional.tex

# %%
results = run_traditional_fs(ds)
# Out:
# ============================================================
# = Running Traditional Feature Selection for: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples:    213577
# Validation samples:  30511
# Test samples:        61022
# Features (original): 63
# k (features to select): 7
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=7)
# ────────────────────────────────────────────────────────────
# Selected features (7): ['LAT', 'LON', 'USA_LON', 'BASIN_EP', 'NATURE_TS', 'WMO_AGENCY_nan', 'USA_STATUS_nan']
# Feature selection time: 30.85s
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI-SQUARE (k=7)
# ────────────────────────────────────────────────────────────
# Selected features (7): ['BASIN_EP', 'BASIN_NI', 'WMO_AGENCY_bom', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_newdelhi', 'WMO_AGENCY_wellington', 'USA_AGENCY_hurdat_epa']
# Feature selection time: 0.12s
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=7, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features (7): ['NUMBER', 'LAT', 'LON', 'USA_LAT', 'USA_LON', 'USA_SSHS', 'BASIN_NI']
# Feature selection time: 26.34s
#
# ────────────────────────────────────────────────────────────
# Constructing FS-Set (Union of Traditional Methods)
# ────────────────────────────────────────────────────────────
# Individual method contributions:
#   mutual_information: ['BASIN_EP', 'LAT', 'LON', 'NATURE_TS', 'USA_LON', 'USA_STATUS_nan', 'WMO_AGENCY_nan']
#   chi2: ['BASIN_EP', 'BASIN_NI', 'USA_AGENCY_hurdat_epa', 'WMO_AGENCY_bom', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_newdelhi', 'WMO_AGENCY_wellington']
#   rfe: ['BASIN_NI', 'LAT', 'LON', 'NUMBER', 'USA_LAT', 'USA_LON', 'USA_SSHS']
#
# FS-Set (union): ['BASIN_EP', 'BASIN_NI', 'LAT', 'LON', 'NATURE_TS', 'NUMBER', 'USA_AGENCY_hurdat_epa', 'USA_LAT', 'USA_LON', 'USA_SSHS', 'USA_STATUS_nan', 'WMO_AGENCY_bom', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_nan', 'WMO_AGENCY_newdelhi', 'WMO_AGENCY_wellington']
# FS-Set size: 16
# Total FS time: 57.31s
#
#   Training random_forest...
#     Training time: 1.96s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9429   0.9328
#     precision      0.8557   0.8861
#     recall         0.3484   0.3912
#     f1_score       0.4952   0.5427
#     auc            0.9675   0.9625
#
#   Training xgboost...
#     Training time: 0.64s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9483   0.9374
#     precision      0.8622   0.8680
#     recall         0.4239   0.4553
#     f1_score       0.5684   0.5973
#     auc            0.9632   0.9554
#
#   Training mlp...
#     Training time: 10.06s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9424   0.9267
#     precision      0.7672   0.7978
#     recall         0.4060   0.3770
#     f1_score       0.5309   0.5121
#     auc            0.9294   0.9186
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/traditional.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/traditional
# Saved LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/traditional.tex
# Saved feature selection LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/traditional_features.tex
