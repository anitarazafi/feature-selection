# %% [markdown]
# ### Traditional Feature selection

# %%
from src.experiments.run_traditional_fs import run_traditional_fs

# %%
#DATASETS = ["ibtracs.last3years"]
DATASETS = ["ibtracs.ALL.list.v04r01"]
all_results = []
for ds in DATASETS:
    results = run_traditional_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL TRADITIONAL FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# Traditional Feature Selection: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples: 578539
# Test samples: 144635
# Original features: 35
#
#
# --- CORRELATION ---
#
# Selecting top 10 features...
# Selected 10 features
# Unique predictions: [0 1]
# Positive predictions: 3
# Unique predictions: [0 1]
# Positive predictions: 13738
# Unique predictions: [0 1]
# Positive predictions: 13402
#   logistic_regression  - F1: 0.0003, AUC: 0.6160
#   random_forest        - F1: 0.8817, AUC: 0.9920
#   xgboost              - F1: 0.8539, AUC: 0.9914
#
# Selecting top 20 features...
# Selected 20 features
# Unique predictions: [0 1]
# Positive predictions: 3187
# Unique predictions: [0 1]
# Positive predictions: 13013
# Unique predictions: [0 1]
# Positive predictions: 12812
#   logistic_regression  - F1: 0.1292, AUC: 0.7882
#   random_forest        - F1: 0.8642, AUC: 0.9915
#   xgboost              - F1: 0.8400, AUC: 0.9892
#
# Selecting top 30 features...
# Selected 30 features
# Unique predictions: [0 1]
# Positive predictions: 2650
# Unique predictions: [0 1]
# Positive predictions: 11278
# Unique predictions: [0 1]
# Positive predictions: 12833
#   logistic_regression  - F1: 0.2117, AUC: 0.8034
#   random_forest        - F1: 0.8035, AUC: 0.9871
#   xgboost              - F1: 0.8320, AUC: 0.9873
#
# --- VARIANCE ---
#
# Selecting top 10 features...
# Selected 10 features
# Unique predictions: [0 1]
# Positive predictions: 3
# Unique predictions: [0 1]
# Positive predictions: 13738
# Unique predictions: [0 1]
# Positive predictions: 13402
#   logistic_regression  - F1: 0.0003, AUC: 0.6160
#   random_forest        - F1: 0.8817, AUC: 0.9920
#   xgboost              - F1: 0.8539, AUC: 0.9914
#
# Selecting top 20 features...
# Selected 20 features
# Unique predictions: [0 1]
# Positive predictions: 3187
# Unique predictions: [0 1]
# Positive predictions: 13013
# Unique predictions: [0 1]
# Positive predictions: 12812
#   logistic_regression  - F1: 0.1292, AUC: 0.7882
#   random_forest        - F1: 0.8642, AUC: 0.9915
#   xgboost              - F1: 0.8400, AUC: 0.9892
#
# Selecting top 30 features...
# Selected 30 features
# Unique predictions: [0 1]
# Positive predictions: 2555
# Unique predictions: [0 1]
# Positive predictions: 11530
# Unique predictions: [0 1]
# Positive predictions: 12683
#   logistic_regression  - F1: 0.1999, AUC: 0.8030
#   random_forest        - F1: 0.8151, AUC: 0.9876
#   xgboost              - F1: 0.8310, AUC: 0.9881
#
# --- CHI_SQUARE ---
#
# Selecting top 10 features...
# Selected 10 features
# Unique predictions: [0]
# Positive predictions: 0
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Unique predictions: [0 1]
# Positive predictions: 3
# Unique predictions: [0 1]
# Positive predictions: 3
#   logistic_regression  - F1: 0.0000, AUC: 0.6907
#   random_forest        - F1: 0.0003, AUC: 0.6658
#   xgboost              - F1: 0.0003, AUC: 0.6652
#
# Selecting top 20 features...
# Selected 20 features
# Unique predictions: [0 1]
# Positive predictions: 398
# Unique predictions: [0 1]
# Positive predictions: 8815
# Unique predictions: [0 1]
# Positive predictions: 6055
#   logistic_regression  - F1: 0.0513, AUC: 0.7238
#   random_forest        - F1: 0.3006, AUC: 0.7520
#   xgboost              - F1: 0.2860, AUC: 0.7894
#
# Selecting top 30 features...
# Selected 30 features
# Unique predictions: [0 1]
# Positive predictions: 154
# Unique predictions: [0 1]
# Positive predictions: 9696
# Unique predictions: [0 1]
# Positive predictions: 9640
#   logistic_regression  - F1: 0.0147, AUC: 0.7521
#   random_forest        - F1: 0.6486, AUC: 0.9495
#   xgboost              - F1: 0.6637, AUC: 0.9654
#
# ============================================================
# Traditional FS complete for ibtracs.ALL.list.v04r01
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/traditional_fs.csv
# ============================================================
#
#
# ============================================================
# ALL TRADITIONAL FEATURE SELECTION COMPLETE
# ============================================================
