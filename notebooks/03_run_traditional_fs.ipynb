# %% [markdown]
# ### Traditional Feature selection

# %%
from src.experiments.run_traditional_fs import run_traditional_fs

# %%
DATASETS = ["ibtracs.last3years"]
#DATASETS = ["ibtracs.ALL.list.v04r01"]
all_results = []
for ds in DATASETS:
    results = run_traditional_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL TRADITIONAL FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# Traditional Feature Selection: ibtracs.last3years
# ============================================================
#
# Training samples: 18620
# Test samples: 4655
# Original features: 61
#
#
# --- CORRELATION ---
#
# Selecting top 10 features...
# Selected 10 features
# Unique predictions: [0]
# Positive predictions: 0
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Unique predictions: [0 1]
# Positive predictions: 274
# Unique predictions: [0 1]
# Positive predictions: 196
#   logistic_regression  - F1: 0.0000, AUC: 0.5103
#   random_forest        - F1: 0.1331, AUC: 0.6360
#   xgboost              - F1: 0.1339, AUC: 0.7172
#
# Selecting top 20 features...
# Selected 20 features
# Unique predictions: [0 1]
# Positive predictions: 21
# Unique predictions: [0 1]
# Positive predictions: 48
# Unique predictions: [0 1]
# Positive predictions: 116
#   logistic_regression  - F1: 0.0000, AUC: 0.5448
#   random_forest        - F1: 0.2413, AUC: 0.8715
#   xgboost              - F1: 0.4752, AUC: 0.9191
#
# Selecting top 30 features...
# Selected 30 features
# Unique predictions: [0 1]
# Positive predictions: 24
# Unique predictions: [0 1]
# Positive predictions: 56
# Unique predictions: [0 1]
# Positive predictions: 158
#   logistic_regression  - F1: 0.1031, AUC: 0.6760
#   random_forest        - F1: 0.2229, AUC: 0.8952
#   xgboost              - F1: 0.4376, AUC: 0.8732
#
# Selecting top 40 features...
# Selected 40 features
# Unique predictions: [0 1]
# Positive predictions: 101
# Unique predictions: [0 1]
# Positive predictions: 59
# Unique predictions: [0 1]
# Positive predictions: 155
#   logistic_regression  - F1: 0.2228, AUC: 0.7937
#   random_forest        - F1: 0.1963, AUC: 0.8974
#   xgboost              - F1: 0.4313, AUC: 0.8687
#
# Selecting top 50 features...
# Selected 50 features
# Unique predictions: [0 1]
# Positive predictions: 101
# Unique predictions: [0 1]
# Positive predictions: 56
# Unique predictions: [0 1]
# Positive predictions: 142
#   logistic_regression  - F1: 0.2500, AUC: 0.7930
#   random_forest        - F1: 0.2291, AUC: 0.8898
#   xgboost              - F1: 0.4254, AUC: 0.8915
#
# --- VARIANCE ---
#
# Selecting top 10 features...
# Selected 10 features
# Unique predictions: [0]
# Positive predictions: 0
# Unique predictions: [0 1]
# Positive predictions: 657
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Unique predictions: [0 1]
# Positive predictions: 634
#   logistic_regression  - F1: 0.0000, AUC: 0.5299
#   random_forest        - F1: 0.0931, AUC: 0.5290
#   xgboost              - F1: 0.0644, AUC: 0.6255
#
# Selecting top 20 features...
# Selected 20 features
# Unique predictions: [0 1]
# Positive predictions: 23
# Unique predictions: [0 1]
# Positive predictions: 56
# Unique predictions: [0 1]
# Positive predictions: 174
#   logistic_regression  - F1: 0.0000, AUC: 0.5327
#   random_forest        - F1: 0.2786, AUC: 0.8757
#   xgboost              - F1: 0.4943, AUC: 0.8903
#
# Selecting top 30 features...
# Selected 30 features
# Unique predictions: [0 1]
# Positive predictions: 18
# Unique predictions: [0 1]
# Positive predictions: 45
# Unique predictions: [0 1]
# Positive predictions: 121
#   logistic_regression  - F1: 0.0912, AUC: 0.6641
#   random_forest        - F1: 0.1731, AUC: 0.8629
#   xgboost              - F1: 0.3711, AUC: 0.8723
#
# Selecting top 40 features...
# Selected 40 features
# Unique predictions: [0 1]
# Positive predictions: 112
# Unique predictions: [0 1]
# Positive predictions: 62
# Unique predictions: [0 1]
# Positive predictions: 144
#   logistic_regression  - F1: 0.2269, AUC: 0.7992
#   random_forest        - F1: 0.2310, AUC: 0.8925
#   xgboost              - F1: 0.3844, AUC: 0.8768
#
# Selecting top 50 features...
# Selected 50 features
# Unique predictions: [0 1]
# Positive predictions: 101
# Unique predictions: [0 1]
# Positive predictions: 45
# Unique predictions: [0 1]
# Positive predictions: 138
#   logistic_regression  - F1: 0.2500, AUC: 0.7921
#   random_forest        - F1: 0.1603, AUC: 0.9036
#   xgboost              - F1: 0.4296, AUC: 0.8665
#
# --- CHI_SQUARE ---
#
# Selecting top 10 features...
# Selected 10 features
# Unique predictions: [0]
# Positive predictions: 0
# Unique predictions: [0 1]
# Positive predictions: 177
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Unique predictions: [0 1]
# Positive predictions: 177
#   logistic_regression  - F1: 0.0000, AUC: 0.6846
#   random_forest        - F1: 0.1577, AUC: 0.6141
#   xgboost              - F1: 0.1577, AUC: 0.6145
#
# Selecting top 20 features...
# Selected 20 features
# Unique predictions: [0]
# Positive predictions: 0
# Unique predictions: [0 1]
# Positive predictions: 11
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Unique predictions: [0 1]
# Positive predictions: 129
#   logistic_regression  - F1: 0.0000, AUC: 0.7023
#   random_forest        - F1: 0.0719, AUC: 0.5210
#   xgboost              - F1: 0.1717, AUC: 0.5334
#
# Selecting top 30 features...
# Selected 30 features
# Unique predictions: [0 1]
# Positive predictions: 22
# Unique predictions: [0 1]
# Positive predictions: 211
# Unique predictions: [0 1]
# Positive predictions: 316
#   logistic_regression  - F1: 0.1038, AUC: 0.7794
#   random_forest        - F1: 0.1841, AUC: 0.8114
#   xgboost              - F1: 0.1509, AUC: 0.7916
#
# Selecting top 40 features...
# Selected 40 features
# Unique predictions: [0 1]
# Positive predictions: 179
# Unique predictions: [0 1]
# Positive predictions: 104
# Unique predictions: [0 1]
# Positive predictions: 231
#   logistic_regression  - F1: 0.2197, AUC: 0.7848
#   random_forest        - F1: 0.2264, AUC: 0.8163
#   xgboost              - F1: 0.2410, AUC: 0.8109
#
# Selecting top 50 features...
# Selected 50 features
# Unique predictions: [0 1]
# Positive predictions: 148
# Unique predictions: [0 1]
# Positive predictions: 57
# Unique predictions: [0 1]
# Positive predictions: 133
#   logistic_regression  - F1: 0.2024, AUC: 0.7795
#   random_forest        - F1: 0.1975, AUC: 0.8915
#   xgboost              - F1: 0.3650, AUC: 0.8787
#
# ============================================================
# Traditional FS complete for ibtracs.last3years
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/traditional_fs.csv
# ============================================================
#
#
# ============================================================
# ALL TRADITIONAL FEATURE SELECTION COMPLETE
# ============================================================
