# %% [markdown]
# ### Traditional Feature selection

# %%
from src.experiments.run_traditional_fs import run_traditional_fs

# %%
ds = "ibtracs.ALL.list.v04r01"
results = run_traditional_fs(ds)
# Out:
# ============================================================
# = Running Traditional Feature Selection for: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples:    213577
# Validation samples:  30511
# Test samples:        61022
# Features (original): 63
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=10)
# ────────────────────────────────────────────────────────────
# Selected features: 10 / 63
# Feature selection time: 31.77s
#
#   Training random_forest...
#   Training time: 1.57s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9499   0.9387
#   precision      0.8635   0.8814
#   recall         0.4463   0.4607
#   f1_score       0.5885   0.6051
#   auc            0.9728   0.9706
#
#   Training xgboost...
#   Training time: 0.51s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9505   0.9397
#   precision      0.8600   0.8703
#   recall         0.4586   0.4810
#   f1_score       0.5982   0.6196
#   auc            0.9640   0.9584
#
#   Training mlp...
#   Training time: 5.80s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9434   0.9253
#   precision      0.7763   0.7401
#   recall         0.4149   0.4132
#   f1_score       0.5408   0.5303
#   auc            0.9139   0.9109
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=30)
# ────────────────────────────────────────────────────────────
# Selected features: 30 / 63
# Feature selection time: 31.17s
#
#   Training random_forest...
#   Training time: 1.69s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9362   0.9240
#   precision      0.8571   0.8988
#   recall         0.2472   0.2869
#   f1_score       0.3838   0.4350
#   auc            0.9579   0.9517
#
#   Training xgboost...
#   Training time: 0.62s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9495   0.9389
#   precision      0.8485   0.8665
#   recall         0.4525   0.4736
#   f1_score       0.5902   0.6124
#   auc            0.9661   0.9596
#
#   Training mlp...
#   Training time: 8.71s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9428   0.9301
#   precision      0.7541   0.7728
#   recall         0.4268   0.4458
#   f1_score       0.5451   0.5654
#   auc            0.9281   0.9229
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=50)
# ────────────────────────────────────────────────────────────
# Selected features: 50 / 63
# Feature selection time: 31.18s
#
#   Training random_forest...
#   Training time: 2.06s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9319   0.9146
#   precision      0.8591   0.8969
#   recall         0.1816   0.1844
#   f1_score       0.2998   0.3059
#   auc            0.9507   0.9429
#
#   Training xgboost...
#   Training time: 0.81s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9491   0.9376
#   precision      0.8551   0.8733
#   recall         0.4406   0.4541
#   f1_score       0.5816   0.5975
#   auc            0.9654   0.9574
#
#   Training mlp...
#   Training time: 9.87s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9396   0.9215
#   precision      0.7357   0.6885
#   recall         0.3872   0.4215
#   f1_score       0.5074   0.5229
#   auc            0.9236   0.9101
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI2 (k=10)
# ────────────────────────────────────────────────────────────
# Selected features: 10 / 63
# Feature selection time: 0.13s
#
#   Training random_forest...
#   Training time: 1.00s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9215   0.9002
#   precision      0.6132   0.6186
#   recall         0.0608   0.0565
#   f1_score       0.1106   0.1036
#   auc            0.8485   0.8207
#
#   Training xgboost...
#   Training time: 0.43s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9203   0.8987
#   precision      0.7000   0.7113
#   recall         0.0143   0.0111
#   f1_score       0.0280   0.0218
#   auc            0.8603   0.8464
#
#   Training mlp...
#   Training time: 2.41s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9197   0.8980
#   precision      0.0000   0.0000
#   recall         0.0000   0.0000
#   f1_score       0.0000   0.0000
#   auc            0.7046   0.6781
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI2 (k=30)
# ────────────────────────────────────────────────────────────
# Selected features: 30 / 63
# Feature selection time: 0.11s
#
#   Training random_forest...
#   Training time: 1.53s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9310   0.9130
#   precision      0.8513   0.8849
#   recall         0.1705   0.1692
#   f1_score       0.2842   0.2840
#   auc            0.9436   0.9313
#
#   Training xgboost...
#   Training time: 0.79s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9463   0.9352
#   precision      0.8418   0.8725
#   recall         0.4080   0.4276
#   f1_score       0.5496   0.5740
#   auc            0.9614   0.9543
#
#   Training mlp...
#   Training time: 7.73s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9452   0.9303
#   precision      0.7896   0.7925
#   recall         0.4333   0.4296
#   f1_score       0.5595   0.5571
#   auc            0.9338   0.9243
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI2 (k=50)
# ────────────────────────────────────────────────────────────
# Selected features: 50 / 63
# Feature selection time: 0.14s
#
#   Training random_forest...
#   Training time: 2.01s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9293   0.9123
#   precision      0.8345   0.8944
#   recall         0.1501   0.1592
#   f1_score       0.2545   0.2703
#   auc            0.9446   0.9324
#
#   Training xgboost...
#   Training time: 0.83s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9479   0.9361
#   precision      0.8596   0.8712
#   recall         0.4198   0.4381
#   f1_score       0.5641   0.5830
#   auc            0.9644   0.9561
#
#   Training mlp...
#   Training time: 6.60s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9407   0.9222
#   precision      0.7198   0.7195
#   recall         0.4296   0.3897
#   f1_score       0.5381   0.5056
#   auc            0.9226   0.8975
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=10, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features: 10 / 63
# Feature selection time: 24.80s
#
#   Training random_forest...
#   Training time: 2.22s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9462   0.9382
#   precision      0.8484   0.8918
#   recall         0.4019   0.4488
#   f1_score       0.5454   0.5971
#   auc            0.9734   0.9706
#
#   Training xgboost...
#   Training time: 0.44s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9494   0.9393
#   precision      0.8475   0.8706
#   recall         0.4512   0.4755
#   f1_score       0.5889   0.6151
#   auc            0.9661   0.9590
#
#   Training mlp...
#   Training time: 7.32s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9442   0.9292
#   precision      0.7736   0.7783
#   recall         0.4308   0.4281
#   f1_score       0.5535   0.5524
#   auc            0.9281   0.9256
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=30, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features: 30 / 63
# Feature selection time: 16.40s
#
#   Training random_forest...
#   Training time: 2.13s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9347   0.9215
#   precision      0.8674   0.9043
#   recall         0.2215   0.2582
#   f1_score       0.3529   0.4016
#   auc            0.9540   0.9518
#
#   Training xgboost...
#   Training time: 0.62s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9485   0.9379
#   precision      0.8532   0.8750
#   recall         0.4341   0.4565
#   f1_score       0.5754   0.6000
#   auc            0.9643   0.9549
#
#   Training mlp...
#   Training time: 10.71s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9435   0.9270
#   precision      0.7626   0.7388
#   recall         0.4313   0.4398
#   f1_score       0.5510   0.5514
#   auc            0.9376   0.9237
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=50, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features: 50 / 63
# Feature selection time: 9.03s
#
#   Training random_forest...
#   Training time: 2.21s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9281   0.9116
#   precision      0.8359   0.8985
#   recall         0.1310   0.1507
#   f1_score       0.2265   0.2581
#   auc            0.9500   0.9422
#
#   Training xgboost...
#   Training time: 0.84s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9487   0.9367
#   precision      0.8444   0.8702
#   recall         0.4427   0.4458
#   f1_score       0.5808   0.5895
#   auc            0.9652   0.9561
#
#   Training mlp...
#   Training time: 13.19s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9406   0.9256
#   precision      0.7422   0.7647
#   recall         0.3994   0.3916
#   f1_score       0.5194   0.5180
#   auc            0.9270   0.9099
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/traditional.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/traditional

# %%
ds = "ibtracs.last3years"
results = run_traditional_fs(ds)
# Out:
# ============================================================
# = Running Traditional Feature Selection for: ibtracs.last3years
# ============================================================
#
# Training samples:    16292
# Validation samples:  2328
# Test samples:        4655
# Features (original): 53
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=10)
# ────────────────────────────────────────────────────────────
# Selected features: 10 / 53
# Feature selection time: 1.60s
#
#   Training random_forest...
#   Training time: 0.22s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9429   0.9487
#   precision      0.9500   0.7500
#   recall         0.1258   0.1573
#   f1_score       0.2222   0.2601
#   auc            0.8213   0.8548
#
#   Training xgboost...
#   Training time: 0.19s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9381   0.9493
#   precision      0.5946   0.6505
#   recall         0.1457   0.2509
#   f1_score       0.2340   0.3622
#   auc            0.8725   0.8734
#
#   Training mlp...
#   Training time: 1.20s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9347   0.9381
#   precision      0.4857   0.4103
#   recall         0.1126   0.1798
#   f1_score       0.1828   0.2500
#   auc            0.8021   0.7854
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=30)
# ────────────────────────────────────────────────────────────
# Selected features: 30 / 53
# Feature selection time: 1.59s
#
#   Training random_forest...
#   Training time: 0.20s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9356   0.9450
#   precision      0.5333   0.7619
#   recall         0.0530   0.0599
#   f1_score       0.0964   0.1111
#   auc            0.7826   0.8398
#
#   Training xgboost...
#   Training time: 0.20s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9373   0.9489
#   precision      0.5490   0.6160
#   recall         0.1854   0.2884
#   f1_score       0.2772   0.3929
#   auc            0.8576   0.8622
#
#   Training mlp...
#   Training time: 1.73s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8436   0.8621
#   precision      0.0920   0.1547
#   recall         0.1589   0.3146
#   f1_score       0.1165   0.2074
#   auc            0.6465   0.7196
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: MUTUAL INFORMATION (k=50)
# ────────────────────────────────────────────────────────────
# Selected features: 50 / 53
# Feature selection time: 1.53s
#
#   Training random_forest...
#   Training time: 0.19s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9351   0.9429
#   precision      0.5000   0.6000
#   recall         0.0331   0.0112
#   f1_score       0.0621   0.0221
#   auc            0.7659   0.8340
#
#   Training xgboost...
#   Training time: 0.24s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9364   0.9510
#   precision      0.5366   0.6512
#   recall         0.1457   0.3146
#   f1_score       0.2292   0.4242
#   auc            0.8514   0.8530
#
#   Training mlp...
#   Training time: 0.67s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.7968   0.8561
#   precision      0.1034   0.1459
#   recall         0.2781   0.3109
#   f1_score       0.1508   0.1986
#   auc            0.6077   0.6894
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI2 (k=10)
# ────────────────────────────────────────────────────────────
# Selected features: 10 / 53
# Feature selection time: 0.01s
#
#   Training random_forest...
#   Training time: 0.14s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9201   0.8834
#   precision      0.0000   0.1057
#   recall         0.0000   0.1386
#   f1_score       0.0000   0.1199
#   auc            0.7496   0.7298
#
#   Training xgboost...
#   Training time: 0.19s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9214   0.8685
#   precision      0.1190   0.1071
#   recall         0.0331   0.1760
#   f1_score       0.0518   0.1331
#   auc            0.8362   0.7680
#
#   Training mlp...
#   Training time: 0.31s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9149   0.8892
#   precision      0.0000   0.0505
#   recall         0.0000   0.0524
#   f1_score       0.0000   0.0515
#   auc            0.5419   0.7072
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI2 (k=30)
# ────────────────────────────────────────────────────────────
# Selected features: 30 / 53
# Feature selection time: 0.00s
#
#   Training random_forest...
#   Training time: 0.17s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9351   0.9433
#   precision      0.5000   0.6667
#   recall         0.0066   0.0225
#   f1_score       0.0131   0.0435
#   auc            0.7891   0.8146
#
#   Training xgboost...
#   Training time: 0.20s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9338   0.9480
#   precision      0.4667   0.5828
#   recall         0.1391   0.3296
#   f1_score       0.2143   0.4211
#   auc            0.8714   0.8558
#
#   Training mlp...
#   Training time: 1.63s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8411   0.9093
#   precision      0.1263   0.1220
#   recall         0.2450   0.0936
#   f1_score       0.1667   0.1059
#   auc            0.6233   0.6533
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: CHI2 (k=50)
# ────────────────────────────────────────────────────────────
# Selected features: 50 / 53
# Feature selection time: 0.01s
#
#   Training random_forest...
#   Training time: 0.19s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9338   0.9424
#   precision      0.3333   0.3333
#   recall         0.0199   0.0037
#   f1_score       0.0375   0.0074
#   auc            0.7724   0.8336
#
#   Training xgboost...
#   Training time: 0.22s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9351   0.9489
#   precision      0.5000   0.6306
#   recall         0.1391   0.2622
#   f1_score       0.2176   0.3704
#   auc            0.8678   0.8508
#
#   Training mlp...
#   Training time: 0.92s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8724   0.9255
#   precision      0.1075   0.1154
#   recall         0.1325   0.0449
#   f1_score       0.1187   0.0647
#   auc            0.6686   0.6809
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=10, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features: 10 / 53
# Feature selection time: 2.20s
#
#   Training random_forest...
#   Training time: 0.22s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9416   0.9467
#   precision      0.8571   0.6610
#   recall         0.1192   0.1461
#   f1_score       0.2093   0.2393
#   auc            0.8181   0.8645
#
#   Training xgboost...
#   Training time: 0.18s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9373   0.9469
#   precision      0.5862   0.5980
#   recall         0.1126   0.2285
#   f1_score       0.1889   0.3306
#   auc            0.8721   0.8653
#
#   Training mlp...
#   Training time: 1.27s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9197   0.9373
#   precision      0.2500   0.4046
#   recall         0.1192   0.1985
#   f1_score       0.1614   0.2663
#   auc            0.7646   0.7761
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=30, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features: 30 / 53
# Feature selection time: 1.27s
#
#   Training random_forest...
#   Training time: 0.21s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9373   0.9467
#   precision      0.7273   0.8065
#   recall         0.0530   0.0936
#   f1_score       0.0988   0.1678
#   auc            0.8195   0.8596
#
#   Training xgboost...
#   Training time: 0.21s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9338   0.9506
#   precision      0.4667   0.6667
#   recall         0.1391   0.2772
#   f1_score       0.2143   0.3915
#   auc            0.8522   0.8583
#
#   Training mlp...
#   Training time: 1.30s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8561   0.8253
#   precision      0.0741   0.1281
#   recall         0.1060   0.3521
#   f1_score       0.0872   0.1878
#   auc            0.6601   0.7293
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: RFE (k=50, estimator=random_forest)
# ────────────────────────────────────────────────────────────
# Selected features: 50 / 53
# Feature selection time: 0.41s
#
#   Training random_forest...
#   Training time: 0.20s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9360   0.9439
#   precision      1.0000   0.8750
#   recall         0.0132   0.0262
#   f1_score       0.0261   0.0509
#   auc            0.7977   0.8233
#
#   Training xgboost...
#   Training time: 0.23s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9347   0.9489
#   precision      0.4872   0.6124
#   recall         0.1258   0.2959
#   f1_score       0.2000   0.3990
#   auc            0.8402   0.8535
#
#   Training mlp...
#   Training time: 1.02s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.7826   0.8533
#   precision      0.0938   0.0985
#   recall         0.2715   0.1910
#   f1_score       0.1395   0.1299
#   auc            0.6316   0.6835
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/traditional.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/models/traditional
