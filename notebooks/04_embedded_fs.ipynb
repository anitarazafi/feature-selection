# %% [markdown]
# ### Run embedded methods

# %%
from src.experiments.run_embedded_fs import run_embedded_fs

# %%
#DATASETS = ["ibtracs.last3years"]
DATASETS = ["ibtracs.ALL.list.v04r01"]
all_results = []
for ds in DATASETS:
    results = run_embedded_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL EMBEDDED FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# Embedded Feature Selection: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples: 578539
#
# Test samples: 144635
# Original features: 35
#
#
# ============================================================
# L1 REGULARIZATION (LASSO)
# ============================================================
#
#
# --- C = 0.001 ---
# Selected 27 features with non-zero coefficients
#   logistic_regression  - F1: 0.1924, AUC: 0.7925
#   random_forest        - F1: 0.8154, AUC: 0.9891
#   xgboost              - F1: 0.8392, AUC: 0.9891
#
# --- C = 0.01 ---
# Selected 30 features with non-zero coefficients
#   logistic_regression  - F1: 0.2158, AUC: 0.8031
#   random_forest        - F1: 0.8076, AUC: 0.9888
#   xgboost              - F1: 0.8330, AUC: 0.9881
#
# --- C = 0.1 ---
# Selected 30 features with non-zero coefficients
#   logistic_regression  - F1: 0.2158, AUC: 0.8031
#   random_forest        - F1: 0.8076, AUC: 0.9888
#   xgboost              - F1: 0.8330, AUC: 0.9881
#
# --- C = 1.0 ---
# Selected 34 features with non-zero coefficients
#   logistic_regression  - F1: 0.2108, AUC: 0.8034
#   random_forest        - F1: 0.7890, AUC: 0.9854
#   xgboost              - F1: 0.8238, AUC: 0.9873
#
# --- C = 10.0 ---
# Selected 35 features with non-zero coefficients
#   logistic_regression  - F1: 0.2122, AUC: 0.8035
#   random_forest        - F1: 0.7903, AUC: 0.9852
#   xgboost              - F1: 0.8291, AUC: 0.9876
#
# ============================================================
# L2 REGULARIZATION (RIDGE)
# ============================================================
#
#
# --- Top 10 features (C=1.0) ---
# Selected 10 features
#   logistic_regression  - F1: 0.0571, AUC: 0.7482
#   random_forest        - F1: 0.8919, AUC: 0.9906
#   xgboost              - F1: 0.8556, AUC: 0.9916
#
# --- Top 20 features (C=1.0) ---
# Selected 20 features
#   logistic_regression  - F1: 0.2053, AUC: 0.8073
#   random_forest        - F1: 0.8669, AUC: 0.9923
#   xgboost              - F1: 0.8406, AUC: 0.9895
#
# --- Top 30 features (C=1.0) ---
# Selected 30 features
#   logistic_regression  - F1: 0.2134, AUC: 0.8033
#   random_forest        - F1: 0.8146, AUC: 0.9884
#   xgboost              - F1: 0.8331, AUC: 0.9885
#
# ============================================================
# Embedded FS complete for ibtracs.ALL.list.v04r01
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/embedded_fs.csv
# ============================================================
#
#
# ============================================================
# ALL EMBEDDED FEATURE SELECTION COMPLETE
# ============================================================
