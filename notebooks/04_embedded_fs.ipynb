# %% [markdown]
# ### Run embedded methods

# %%
from src.experiments.run_embedded_fs import run_embedded_fs

# %%
DATASETS = ["ibtracs.last3years"]
#DATASETS = ["ibtracs.ALL.list.v04r01"]
all_results = []
for ds in DATASETS:
    results = run_embedded_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL EMBEDDED FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# Embedded Feature Selection: ibtracs.last3years
# ============================================================
#
# Training samples: 18620
#
# Test samples: 4655
# Original features: 61
#
#
# ============================================================
# L1 REGULARIZATION (LASSO)
# ============================================================
#
#
# --- C = 0.001 ---
# Selected 10 features with non-zero coefficients
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#   logistic_regression  - F1: 0.0000, AUC: 0.6499
#   random_forest        - F1: 0.1250, AUC: 0.6625
#   xgboost              - F1: 0.1250, AUC: 0.6625
#
# --- C = 0.01 ---
# Selected 27 features with non-zero coefficients
#   logistic_regression  - F1: 0.2185, AUC: 0.7664
#   random_forest        - F1: 0.1053, AUC: 0.8425
#   xgboost              - F1: 0.3792, AUC: 0.8980
#
# --- C = 0.1 ---
# Selected 51 features with non-zero coefficients
#   logistic_regression  - F1: 0.2459, AUC: 0.7904
#   random_forest        - F1: 0.1742, AUC: 0.8743
#   xgboost              - F1: 0.3510, AUC: 0.8742
#
# --- C = 1.0 ---
# Selected 57 features with non-zero coefficients
#   logistic_regression  - F1: 0.2459, AUC: 0.7908
#   random_forest        - F1: 0.1818, AUC: 0.8979
#   xgboost              - F1: 0.3068, AUC: 0.8700
#
# --- C = 10.0 ---
# Selected 61 features with non-zero coefficients
#   logistic_regression  - F1: 0.2459, AUC: 0.7907
#   random_forest        - F1: 0.1770, AUC: 0.8829
#   xgboost              - F1: 0.4171, AUC: 0.8437
#
# ============================================================
# L2 REGULARIZATION (RIDGE)
# ============================================================
#
#
# --- Top 10 features (C=1.0) ---
# Selected 10 features
# /Users/anitarazafi/Desktop/masters/code/feature-selection/venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#   logistic_regression  - F1: 0.0000, AUC: 0.6804
#   random_forest        - F1: 0.2204, AUC: 0.8026
#   xgboost              - F1: 0.2148, AUC: 0.8475
#
# --- Top 20 features (C=1.0) ---
# Selected 20 features
#   logistic_regression  - F1: 0.2028, AUC: 0.7663
#   random_forest        - F1: 0.4354, AUC: 0.9180
#   xgboost              - F1: 0.5093, AUC: 0.9261
#
# --- Top 30 features (C=1.0) ---
# Selected 30 features
#   logistic_regression  - F1: 0.2537, AUC: 0.7841
#   random_forest        - F1: 0.4085, AUC: 0.9246
#   xgboost              - F1: 0.4821, AUC: 0.9294
#
# --- Top 40 features (C=1.0) ---
# Selected 40 features
#   logistic_regression  - F1: 0.2541, AUC: 0.7914
#   random_forest        - F1: 0.1863, AUC: 0.9035
#   xgboost              - F1: 0.4741, AUC: 0.9279
#
# --- Top 50 features (C=1.0) ---
# Selected 50 features
#   logistic_regression  - F1: 0.2486, AUC: 0.7903
#   random_forest        - F1: 0.1812, AUC: 0.8874
#   xgboost              - F1: 0.2735, AUC: 0.8802
#
# ============================================================
# Embedded FS complete for ibtracs.last3years
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/embedded_fs.csv
# ============================================================
#
#
# ============================================================
# ALL EMBEDDED FEATURE SELECTION COMPLETE
# ============================================================
