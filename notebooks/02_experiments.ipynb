# %% [markdown]
# ### Run baseline, models without feature selection

# %%
from experiments.run_baseline import train_baseline
import pandas as pd
from src.utils.paths import COMPARISONS_DIR

# %%
DATASETS = ["ibtracs.last3years"]

# %%
all_results = []
for ds in DATASETS:
    results = train_baseline(ds)
    all_results.append(results)

# Combine all results
combined = pd.concat(all_results, ignore_index=True)
combined.to_csv(COMPARISONS_DIR / "tables" / "baseline_all.csv", index=False)
print("\n" + "="*50)
print("BASELINE TRAINING COMPLETE")
print("="*50)
print(combined.to_string(index=False))
# Out:
# ==================================================
# Training baseline models for: ibtracs.last3years
# ==================================================
#
# Training samples: 18620
# Test samples: 4656
# Features: 63
#
# Training logistic_regression...
#   - Accuracy: 0.9766
#   - F1 Score: 0.8180
#   - AUC: 0.9901
#   - Training time: 0.04s
#
# Training random_forest...
#   - Accuracy: 0.9805
#   - F1 Score: 0.8226
#   - AUC: 0.9911
#   - Training time: 0.24s
#
# Training xgboost...
#   - Accuracy: 0.9798
#   - F1 Score: 0.8199
#   - AUC: 0.9939
#   - Training time: 0.18s
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/comparisons/tables/baseline_ibtracs.last3years.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/models/baseline/ibtracs.last3years
#
#
# ==================================================
# BASELINE TRAINING COMPLETE
# ==================================================
#            dataset               model   method  n_features  accuracy  f1_score      auc  train_time
# ibtracs.last3years logistic_regression baseline          63  0.976589  0.818030 0.990082    0.037243
# ibtracs.last3years       random_forest baseline          63  0.980455  0.822612 0.991066    0.237471
# ibtracs.last3years             xgboost baseline          63  0.979811  0.819923 0.993931    0.180656
