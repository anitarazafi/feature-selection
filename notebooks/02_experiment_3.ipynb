# %%
from src.experiments.run_optimization_fs import run_optimization_fs

# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
results = run_optimization_fs(ds)
# Out:
# ============================================================
# = Running Optimization-Based Feature Selection for: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples:    213577
# Validation samples:  30511
# Test samples:        61022
# Features (original): 63
# k (features to select): 7
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: PSO (k=7)
# ────────────────────────────────────────────────────────────
#   PSO best val AUC: 0.9633
# Selected features (7): ['LAT', 'USA_AGENCY_jtwc_sh', 'USA_STATUS_XX', 'USA_LON', 'BASIN_SP', 'LON', 'NATURE_ET']
# Feature selection time: 236.64s
#
# ────────────────────────────────────────────────────────────
# Feature Selection: DIFFERENTIAL EVOLUTION (k=7)
# ────────────────────────────────────────────────────────────
# differential_evolution step 1: f(x)= 0.03305749933187985
# differential_evolution step 2: f(x)= 0.03305749933187985
# differential_evolution step 3: f(x)= 0.03305749933187985
# differential_evolution step 4: f(x)= 0.03305749933187985
# differential_evolution step 5: f(x)= 0.03305749933187985
# differential_evolution step 6: f(x)= 0.03305749933187985
# differential_evolution step 7: f(x)= 0.03305749933187985
# differential_evolution step 8: f(x)= 0.03305749933187985
# differential_evolution step 9: f(x)= 0.03305749933187985
# differential_evolution step 10: f(x)= 0.03305749933187985
# differential_evolution step 11: f(x)= 0.03305749933187985
# differential_evolution step 12: f(x)= 0.03305749933187985
# differential_evolution step 13: f(x)= 0.03305749933187985
# differential_evolution step 14: f(x)= 0.03305749933187985
# differential_evolution step 15: f(x)= 0.03305749933187985
# differential_evolution step 16: f(x)= 0.03305749933187985
# differential_evolution step 17: f(x)= 0.03305749933187985
# differential_evolution step 18: f(x)= 0.03305749933187985
# differential_evolution step 19: f(x)= 0.03305749933187985
# differential_evolution step 20: f(x)= 0.03305749933187985
#   DE best val AUC: 0.9669
# Selected features (7): ['NATURE_DS', 'USA_LAT', 'USA_STATUS_SS', 'LAT', 'USA_LON', 'USA_AGENCY_cphc', 'LON']
# Feature selection time: 534.49s
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SIMPLE GA (k=7)
# ────────────────────────────────────────────────────────────
#   GA Gen  0: best AUC = 0.9212
#   GA Gen  5: best AUC = 0.9647
#   GA Gen 10: best AUC = 0.9680
#   GA Gen 15: best AUC = 0.9680
#   GA Gen 20: best AUC = 0.9682
#   GA Gen 25: best AUC = 0.9682
#   GA Gen 30: best AUC = 0.9682
#   GA best val AUC: 0.9682
# Selected features (7): ['LAT', 'LON', 'USA_LAT', 'USA_LON', 'STORM_SPEED', 'BASIN_SI', 'WMO_AGENCY_newdelhi']
# Feature selection time: 634.65s
#
# ────────────────────────────────────────────────────────────
# Constructing Op-Set (Union of Optimization Methods)
# ────────────────────────────────────────────────────────────
# Individual method contributions:
#   pso: ['BASIN_SP', 'LAT', 'LON', 'NATURE_ET', 'USA_AGENCY_jtwc_sh', 'USA_LON', 'USA_STATUS_XX']
#   differential_evolution: ['LAT', 'LON', 'NATURE_DS', 'USA_AGENCY_cphc', 'USA_LAT', 'USA_LON', 'USA_STATUS_SS']
#   simple_ga: ['BASIN_SI', 'LAT', 'LON', 'STORM_SPEED', 'USA_LAT', 'USA_LON', 'WMO_AGENCY_newdelhi']
#
# Op-Set (union): ['BASIN_SI', 'BASIN_SP', 'LAT', 'LON', 'NATURE_DS', 'NATURE_ET', 'STORM_SPEED', 'USA_AGENCY_cphc', 'USA_AGENCY_jtwc_sh', 'USA_LAT', 'USA_LON', 'USA_STATUS_SS', 'USA_STATUS_XX', 'WMO_AGENCY_newdelhi']
# Op-Set size: 14
# Total FS time: 1405.78s
#
#   Training random_forest...
#     Training time: 1.60s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9396   0.9310
#     precision      0.8689   0.9197
#     recall         0.2921   0.3549
#     f1_score       0.4373   0.5121
#     auc            0.9662   0.9622
#
#   Training xgboost...
#     Training time: 0.49s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9495   0.9373
#     precision      0.8595   0.8703
#     recall         0.4443   0.4525
#     f1_score       0.5858   0.5954
#     auc            0.9662   0.9564
#
#   Training mlp...
#     Training time: 7.24s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9462   0.9292
#     precision      0.7825   0.7733
#     recall         0.4565   0.4323
#     f1_score       0.5767   0.5546
#     auc            0.9361   0.9224
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/optimization.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/optimization
# Saved LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/optimization.tex
# Saved feature selection LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/optimization_features.tex

# %%
from src.experiments.run_xai_fs import run_xai_fs

# %%
results = run_xai_fs(ds)
# Out:
# ============================================================
# = Running XAI-Based Feature Selection for: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples:    213577
# Validation samples:  30511
# Test samples:        61022
# Features (original): 63
# k (features to select): 7
#
# Pre-training explainer model (XGBoost) for SHAP, LIME, and PI...
#
# Pre-trained PI estimator: random_forest
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SHAP (k=7)
# ────────────────────────────────────────────────────────────
# 100%|===================| 9984/10000 [00:21<00:00]
# Selected features (7): ['LON', 'LAT', 'USA_LON', 'STORM_SPEED', 'BASIN_SI', 'BASIN_WP', 'BASIN_NI']
# Feature selection time: 20.14s
#
# ────────────────────────────────────────────────────────────
# Feature Selection: LIME (k=7)
# ────────────────────────────────────────────────────────────
#   Running LIME on 500 samples...
#   LIME progress: 0/500
#   LIME progress: 100/500
#   LIME progress: 200/500
#   LIME progress: 300/500
#   LIME progress: 400/500
# Selected features (7): ['BASIN_NI', 'USA_AGENCY_atcf', 'LAT', 'WMO_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'LON', 'USA_STATUS_WV']
# Feature selection time: 16.27s
#
# ────────────────────────────────────────────────────────────
# Feature Selection: PERMUTATION IMPORTANCE (k=7)
# ────────────────────────────────────────────────────────────
#   Computing permutation importance (10 repeats, 10000 samples)...
# Selected features (7): ['LON', 'USA_LON', 'LAT', 'USA_LAT', 'BASIN_EP', 'BASIN_NI', 'USA_SSHS']
# Feature selection time: 9.51s
#
# ────────────────────────────────────────────────────────────
# Constructing X-Set (Union of XAI Methods)
# ────────────────────────────────────────────────────────────
# Individual method contributions:
#   shap: ['BASIN_NI', 'BASIN_SI', 'BASIN_WP', 'LAT', 'LON', 'STORM_SPEED', 'USA_LON']
#   lime: ['BASIN_NI', 'LAT', 'LON', 'USA_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'USA_STATUS_WV', 'WMO_AGENCY_atcf']
#   permutation_importance: ['BASIN_EP', 'BASIN_NI', 'LAT', 'LON', 'USA_LAT', 'USA_LON', 'USA_SSHS']
#
# X-Set (union): ['BASIN_EP', 'BASIN_NI', 'BASIN_SI', 'BASIN_WP', 'LAT', 'LON', 'STORM_SPEED', 'USA_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'USA_LAT', 'USA_LON', 'USA_SSHS', 'USA_STATUS_WV', 'WMO_AGENCY_atcf']
# X-Set size: 14
# Total FS time: 45.92s
#
#   Training random_forest...
#     Training time: 1.64s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9429   0.9338
#     precision      0.8761   0.9109
#     recall         0.3374   0.3891
#     f1_score       0.4872   0.5452
#     auc            0.9734   0.9705
#
#   Training xgboost...
#     Training time: 0.46s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9486   0.9371
#     precision      0.8445   0.8790
#     recall         0.4410   0.4448
#     f1_score       0.5795   0.5907
#     auc            0.9668   0.9584
#
#   Training mlp...
#     Training time: 7.15s
#     Metric            Val     Test
#     ------------------------------
#     accuracy       0.9471   0.9327
#     precision      0.7676   0.7623
#     recall         0.4892   0.4941
#     f1_score       0.5976   0.5996
#     auc            0.9375   0.9295
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/xai.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/xai
# Saved LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/xai.tex
# Saved feature selection LaTeX table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/xai_features.tex
