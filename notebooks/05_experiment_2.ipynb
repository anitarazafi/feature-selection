# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
from src.experiments_new.run_repeated_experiments import run_all_experiments
combined_df, summary_df = run_all_experiments(
    ds,
    k_traditional=7,    # from sweep results
    k_optimization=13,   # from sweep results
    k_xai=10            # from sweep results
)
# Out:
# ############################################################
# # REPEATED EXPERIMENTS: 10 seeds
# # Seeds: [42, 123, 456, 789, 1024, 2023, 2024, 3333, 5555, 9999]
# # Dataset: ibtracs.ALL.list.v04r01
# # k values: traditional=7, optimization=13, xai=10
# ############################################################
#
#
# ************************************************************
# * RUN 1/10 — seed=42
# ************************************************************
#
# ...
# = Training baseline models for: ibtracs.ALL.list.v04r01 (seed=42)
# Training samples:   213577
# Validation samples: 30511
# Test samples:       61022
# Features: 63
#
# Training random_forest...
#   Training time: 1.87s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9266   0.9073
#   precision      0.8371   0.8878
#   recall         0.1069   0.1043
#   f1_score       0.1896   0.1866
#   auc            0.9390   0.9299
#
# Training xgboost...
#   Training time: 0.93s
# ...
