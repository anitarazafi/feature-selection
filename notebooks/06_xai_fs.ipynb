# %% [markdown]
# ### Run xai methods

# %%
from src.experiments.run_xai_fs import run_xai_fs

# %%
ds = "ibtracs.ALL.list.v04r01"
results = run_xai_fs(ds)
# Out:
# ============================================================
# = Running XAI-Based Feature Selection for: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples:    213577
# Validation samples:  30511
# Test samples:        61022
# Features (original): 63
#
# Pre-training explainer model (XGBoost) for SHAP and LIME...
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SHAP (k=10)
# ────────────────────────────────────────────────────────────
# 100%|===================| 9959/10000 [00:26<00:00]
# Selected features: 10 / 63
# Feature selection time: 25.66s
# Top features: ['LON', 'LAT', 'USA_LON', 'STORM_SPEED', 'BASIN_SI', 'BASIN_WP', 'USA_WIND', 'BASIN_nan', 'USA_LAT', 'USA_SSHS']
#
#   Training random_forest...
#   Training time: 2.42s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9525   0.9418
#   precision      0.8705   0.8904
#   recall         0.4798   0.4895
#   f1_score       0.6186   0.6317
#   auc            0.9754   0.9743
#
#   Training xgboost...
#   Training time: 0.54s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9496   0.9380
#   precision      0.8446   0.8772
#   recall         0.4570   0.4557
#   f1_score       0.5931   0.5999
#   auc            0.9656   0.9565
#
#   Training mlp...
#   Training time: 8.44s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9438   0.9297
#   precision      0.7612   0.7832
#   recall         0.4382   0.4294
#   f1_score       0.5562   0.5547
#   auc            0.9334   0.9288
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SHAP (k=30)
# ────────────────────────────────────────────────────────────
#  99%|===================| 9900/10000 [00:25<00:00]
# Selected features: 30 / 63
# Feature selection time: 25.10s
# Top features: ['LON', 'LAT', 'USA_LON', 'STORM_SPEED', 'BASIN_SI', 'BASIN_WP', 'BASIN_nan', 'USA_WIND', 'USA_LAT', 'USA_SSHS', 'BASIN_EP', 'BASIN_NI', 'STORM_DIR', 'SEASON', 'BASIN_SP', 'WMO_AGENCY_bom', 'WMO_PRES', 'NUMBER', 'USA_PRES', 'NATURE_DS', 'NATURE_NR', 'USA_AGENCY_nan', 'NATURE_ET', 'USA_AGENCY_jtwc_wp', 'NATURE_TS', 'USA_STATUS_DB', 'USA_STATUS_HU', 'WMO_AGENCY_nan', 'USA_STATUS_nan', 'USA_STATUS_TD']
#
#   Training random_forest...
#   Training time: 2.71s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9344   0.9227
#   precision      0.8594   0.8999
#   recall         0.2195   0.2729
#   f1_score       0.3497   0.4188
#   auc            0.9561   0.9521
#
#   Training xgboost...
#   Training time: 0.80s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9474   0.9366
#   precision      0.8438   0.8781
#   recall         0.4231   0.4397
#   f1_score       0.5636   0.5860
#   auc            0.9625   0.9547
#
#   Training mlp...
#   Training time: 10.54s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9398   0.9138
#   precision      0.6520   0.5785
#   recall         0.5373   0.5717
#   f1_score       0.5891   0.5751
#   auc            0.9317   0.9150
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SHAP (k=50)
# ────────────────────────────────────────────────────────────
# 100%|===================| 9952/10000 [00:25<00:00]
# Selected features: 50 / 63
# Feature selection time: 25.01s
# Top features: ['LON', 'LAT', 'USA_LON', 'STORM_SPEED', 'BASIN_SI', 'BASIN_WP', 'BASIN_EP', 'USA_LAT', 'USA_SSHS', 'USA_WIND', 'BASIN_NI', 'BASIN_nan', 'STORM_DIR', 'SEASON', 'BASIN_SP', 'NUMBER', 'WMO_AGENCY_bom', 'WMO_PRES', 'USA_PRES', 'NATURE_DS', 'NATURE_NR', 'USA_AGENCY_nan', 'NATURE_ET', 'NATURE_TS', 'USA_STATUS_DB', 'USA_STATUS_TD', 'USA_AGENCY_jtwc_wp', 'USA_AGENCY_hurdat_epa', 'WMO_AGENCY_nan', 'USA_STATUS_nan', 'USA_STATUS_HU', 'WMO_AGENCY_newdelhi', 'BASIN_SA', 'NATURE_MX', 'USA_STATUS_LO', 'WMO_AGENCY_atcf', 'TRACK_TYPE_main', 'NATURE_SS', 'WMO_AGENCY_hurdat_atl', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_nadi', 'WMO_AGENCY_reunion', 'WMO_AGENCY_tokyo', 'WMO_AGENCY_wellington', 'TRACK_TYPE_nan', 'USA_AGENCY_atcf', 'USA_AGENCY_cphc', 'USA_AGENCY_hurdat_atl', 'USA_AGENCY_jtwc_cp', 'USA_AGENCY_jtwc_ep']
#
#   Training random_forest...
#   Training time: 2.58s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9313   0.9135
#   precision      0.8515   0.8871
#   recall         0.1754   0.1741
#   f1_score       0.2909   0.2911
#   auc            0.9502   0.9427
#
#   Training xgboost...
#   Training time: 1.05s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9484   0.9369
#   precision      0.8439   0.8684
#   recall         0.4390   0.4495
#   f1_score       0.5776   0.5924
#   auc            0.9647   0.9557
#
#   Training mlp...
#   Training time: 8.30s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9400   0.9259
#   precision      0.7453   0.7580
#   recall         0.3843   0.4026
#   f1_score       0.5071   0.5259
#   auc            0.9259   0.9056
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: LIME (k=10)
# ────────────────────────────────────────────────────────────
#   Running LIME on 500 samples...
#   LIME progress: 0/500
#   LIME progress: 100/500
#   LIME progress: 200/500
#   LIME progress: 300/500
#   LIME progress: 400/500
# Selected features: 10 / 63
# Feature selection time: 19.96s
# Top features: ['BASIN_NI', 'LAT', 'LON', 'USA_STATUS_WV', 'BASIN_SA', 'USA_STATUS_SD', 'USA_AGENCY_jtwc_cp', 'USA_STATUS_TC', 'USA_AGENCY_atcf', 'WMO_AGENCY_atcf']
#
#   Training random_forest...
#   Training time: 1.35s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9414   0.9290
#   precision      0.8756   0.9175
#   recall         0.3158   0.3340
#   f1_score       0.4642   0.4897
#   auc            0.9632   0.9581
#
#   Training xgboost...
#   Training time: 0.51s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9496   0.9363
#   precision      0.8519   0.8890
#   recall         0.4504   0.4296
#   f1_score       0.5893   0.5792
#   auc            0.9629   0.9536
#
#   Training mlp...
#   Training time: 9.53s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9439   0.9289
#   precision      0.7302   0.7407
#   recall         0.4782   0.4662
#   f1_score       0.5779   0.5722
#   auc            0.9304   0.9193
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: LIME (k=30)
# ────────────────────────────────────────────────────────────
#   Running LIME on 500 samples...
#   LIME progress: 0/500
#   LIME progress: 100/500
#   LIME progress: 200/500
#   LIME progress: 300/500
#   LIME progress: 400/500
# Selected features: 30 / 63
# Feature selection time: 19.95s
# Top features: ['BASIN_NI', 'USA_STATUS_WV', 'LAT', 'LON', 'USA_AGENCY_jtwc_cp', 'BASIN_SA', 'USA_AGENCY_jtwc_ep', 'USA_AGENCY_atcf', 'WMO_AGENCY_atcf', 'USA_STATUS_SD', 'USA_AGENCY_cphc', 'USA_STATUS_TC', 'USA_STATUS_SS', 'BASIN_WP', 'USA_STATUS_ST', 'NATURE_SS', 'TRACK_TYPE_nan', 'STORM_SPEED', 'WMO_AGENCY_nadi', 'USA_STATUS_HR', 'BASIN_SI', 'BASIN_nan', 'USA_STATUS_XX', 'USA_STATUS_EX', 'WMO_AGENCY_wellington', 'WMO_AGENCY_newdelhi', 'USA_STATUS_LO', 'USA_SSHS', 'USA_AGENCY_jtwc_io', 'USA_STATUS_DB']
#
#   Training random_forest...
#   Training time: 1.35s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9278   0.9072
#   precision      0.8159   0.8837
#   recall         0.1302   0.1038
#   f1_score       0.2245   0.1857
#   auc            0.9370   0.9237
#
#   Training xgboost...
#   Training time: 0.77s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9483   0.9351
#   precision      0.8512   0.8824
#   recall         0.4317   0.4196
#   f1_score       0.5728   0.5688
#   auc            0.9634   0.9526
#
#   Training mlp...
#   Training time: 14.71s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9452   0.9296
#   precision      0.7479   0.7778
#   recall         0.4794   0.4342
#   f1_score       0.5843   0.5573
#   auc            0.9383   0.9129
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: LIME (k=50)
# ────────────────────────────────────────────────────────────
#   Running LIME on 500 samples...
#   LIME progress: 0/500
#   LIME progress: 100/500
#   LIME progress: 200/500
#   LIME progress: 300/500
#   LIME progress: 400/500
# Selected features: 50 / 63
# Feature selection time: 20.56s
# Top features: ['BASIN_NI', 'LAT', 'USA_AGENCY_jtwc_cp', 'LON', 'USA_STATUS_WV', 'USA_STATUS_TC', 'BASIN_SA', 'USA_STATUS_SD', 'USA_AGENCY_atcf', 'USA_STATUS_SS', 'USA_STATUS_ST', 'USA_AGENCY_jtwc_ep', 'WMO_AGENCY_atcf', 'USA_STATUS_HR', 'BASIN_WP', 'TRACK_TYPE_nan', 'NATURE_SS', 'STORM_SPEED', 'USA_STATUS_ET', 'WMO_AGENCY_nadi', 'USA_AGENCY_cphc', 'BASIN_SI', 'BASIN_nan', 'USA_STATUS_XX', 'USA_STATUS_EX', 'WMO_AGENCY_wellington', 'USA_AGENCY_jtwc_io', 'USA_STATUS_LO', 'WMO_AGENCY_newdelhi', 'USA_STATUS_DB', 'USA_SSHS', 'BASIN_SP', 'USA_WIND', 'WMO_AGENCY_bom', 'NATURE_DS', 'NATURE_NR', 'NATURE_MX', 'USA_STATUS_TY', 'NATURE_ET', 'WMO_AGENCY_hurdat_atl', 'USA_AGENCY_hurdat_atl', 'WMO_AGENCY_reunion', 'WMO_AGENCY_hurdat_epa', 'USA_STATUS_HU', 'USA_AGENCY_hurdat_epa', 'BASIN_EP', 'USA_STATUS_TD', 'WMO_PRES', 'STORM_DIR', 'WMO_AGENCY_tokyo']
#
#   Training random_forest...
#   Training time: 2.29s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9263   0.9063
#   precision      0.8202   0.8860
#   recall         0.1061   0.0937
#   f1_score       0.1879   0.1694
#   auc            0.9269   0.9125
#
#   Training xgboost...
#   Training time: 1.01s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9490   0.9354
#   precision      0.8482   0.8835
#   recall         0.4447   0.4227
#   f1_score       0.5835   0.5718
#   auc            0.9621   0.9517
#
#   Training mlp...
#   Training time: 12.97s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9438   0.9296
#   precision      0.7543   0.7724
#   recall         0.4447   0.4389
#   f1_score       0.5595   0.5597
#   auc            0.9246   0.9078
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/xai.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/xai

# %%
ds = "ibtracs.last3years"
results = run_xai_fs(ds)
# Out:
# ============================================================
# = Running XAI-Based Feature Selection for: ibtracs.last3years
# ============================================================
#
# Training samples:    16292
# Validation samples:  2328
# Test samples:        4655
# Features (original): 53
#
# Pre-training explainer model (XGBoost) for SHAP and LIME...
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SHAP (k=10)
# ────────────────────────────────────────────────────────────
#  99%|===================| 9946/10000 [00:28<00:00]
# Selected features: 10 / 53
# Feature selection time: 27.86s
# Top features: ['LON', 'LAT', 'USA_POCI', 'USA_LON', 'USA_RMW', 'USA_SSHS', 'STORM_SPEED', 'USA_ROCI', 'BASIN_nan', 'USA_WIND']
#
#   Training random_forest...
#   Training time: 0.24s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9420   0.9478
#   precision      0.9000   0.6538
#   recall         0.1192   0.1910
#   f1_score       0.2105   0.2957
#   auc            0.8368   0.8615
#
#   Training xgboost...
#   Training time: 0.25s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9381   0.9519
#   precision      0.6129   0.6617
#   recall         0.1258   0.3296
#   f1_score       0.2088   0.4400
#   auc            0.8540   0.8731
#
#   Training mlp...
#   Training time: 1.24s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9283   0.9368
#   precision      0.3400   0.3579
#   recall         0.1126   0.1273
#   f1_score       0.1692   0.1878
#   auc            0.7996   0.8057
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SHAP (k=30)
# ────────────────────────────────────────────────────────────
#  98%|===================| 9807/10000 [00:28<00:00]
# Selected features: 30 / 53
# Feature selection time: 28.43s
# Top features: ['LON', 'LAT', 'USA_LON', 'USA_POCI', 'USA_RMW', 'USA_ROCI', 'STORM_SPEED', 'USA_SSHS', 'USA_WIND', 'USA_LAT', 'NUMBER', 'BASIN_nan', 'USA_R34_SW', 'USA_R34_NW', 'SEASON', 'BASIN_EP', 'STORM_DIR', 'USA_STATUS_LO', 'USA_PRES', 'BASIN_NI', 'NATURE_NR', 'USA_R34_SE', 'BASIN_SI', 'TRACK_TYPE_main', 'BASIN_WP', 'USA_STATUS_TS', 'NATURE_ET', 'BASIN_SP', 'USA_R34_NE', 'USA_STATUS_DB']
#
#   Training random_forest...
#   Training time: 0.24s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9343   0.9435
#   precision      0.4444   0.6250
#   recall         0.0530   0.0375
#   f1_score       0.0947   0.0707
#   auc            0.8130   0.8535
#
#   Training xgboost...
#   Training time: 0.29s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9369   0.9512
#   precision      0.5500   0.6667
#   recall         0.1457   0.2996
#   f1_score       0.2304   0.4134
#   auc            0.8607   0.8651
#
#   Training mlp...
#   Training time: 1.39s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8827   0.9091
#   precision      0.1090   0.1250
#   recall         0.1126   0.0974
#   f1_score       0.1107   0.1095
#   auc            0.6420   0.7142
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: SHAP (k=50)
# ────────────────────────────────────────────────────────────
#  96%|=================== | 9637/10000 [00:28<00:01]
# Selected features: 50 / 53
# Feature selection time: 28.39s
# Top features: ['LON', 'LAT', 'USA_LON', 'USA_POCI', 'USA_RMW', 'USA_ROCI', 'STORM_SPEED', 'USA_SSHS', 'USA_WIND', 'NUMBER', 'BASIN_nan', 'USA_LAT', 'USA_R34_SW', 'USA_R34_NW', 'SEASON', 'STORM_DIR', 'BASIN_EP', 'NATURE_NR', 'USA_PRES', 'BASIN_NI', 'USA_STATUS_LO', 'USA_R34_SE', 'BASIN_SI', 'BASIN_WP', 'TRACK_TYPE_main', 'NATURE_ET', 'BASIN_SP', 'USA_STATUS_TS', 'USA_STATUS_DB', 'USA_R34_NE', 'NATURE_TS', 'NATURE_DS', 'USA_STATUS_TY', 'USA_STATUS_nan', 'TRACK_TYPE_nan', 'USA_STATUS_TD', 'NATURE_MX', 'USA_STATUS_EX', 'USA_AGENCY_hurdat_atl', 'USA_STATUS_SS', 'NATURE_SS', 'USA_AGENCY_atcf', 'USA_AGENCY_hurdat_epa', 'USA_AGENCY_jtwc_io', 'USA_AGENCY_jtwc_sh', 'USA_AGENCY_jtwc_wp', 'USA_AGENCY_nan', 'USA_STATUS_HU', 'USA_STATUS_MD', 'USA_STATUS_SD']
#
#   Training random_forest...
#   Training time: 0.25s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9360   0.9441
#   precision      1.0000   0.6296
#   recall         0.0132   0.0637
#   f1_score       0.0261   0.1156
#   auc            0.7850   0.8419
#
#   Training xgboost...
#   Training time: 0.31s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9369   0.9530
#   precision      0.5476   0.7143
#   recall         0.1523   0.2996
#   f1_score       0.2383   0.4222
#   auc            0.8459   0.8583
#
#   Training mlp...
#   Training time: 2.13s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8840   0.8629
#   precision      0.1394   0.1207
#   recall         0.1523   0.2210
#   f1_score       0.1456   0.1561
#   auc            0.6659   0.6770
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: LIME (k=10)
# ────────────────────────────────────────────────────────────
#   Running LIME on 500 samples...
#   LIME progress: 0/500
#   LIME progress: 100/500
#   LIME progress: 200/500
#   LIME progress: 300/500
#   LIME progress: 400/500
# Selected features: 10 / 53
# Feature selection time: 20.98s
# Top features: ['USA_AGENCY_atcf', 'LON', 'LAT', 'USA_STATUS_WV', 'USA_POCI', 'USA_RMW', 'BASIN_nan', 'NATURE_NR', 'USA_ROCI', 'STORM_SPEED']
#
#   Training random_forest...
#   Training time: 0.18s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9390   0.9484
#   precision      0.9091   0.7755
#   recall         0.0662   0.1423
#   f1_score       0.1235   0.2405
#   auc            0.7872   0.8499
#
#   Training xgboost...
#   Training time: 0.25s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9347   0.9469
#   precision      0.4839   0.5610
#   recall         0.0993   0.3446
#   f1_score       0.1648   0.4269
#   auc            0.8673   0.8676
#
#   Training mlp...
#   Training time: 1.48s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9119   0.9207
#   precision      0.1625   0.2102
#   recall         0.0861   0.1386
#   f1_score       0.1126   0.1670
#   auc            0.7760   0.7801
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: LIME (k=30)
# ────────────────────────────────────────────────────────────
#   Running LIME on 500 samples...
#   LIME progress: 0/500
#   LIME progress: 100/500
#   LIME progress: 200/500
#   LIME progress: 300/500
#   LIME progress: 400/500
# Selected features: 30 / 53
# Feature selection time: 21.93s
# Top features: ['LON', 'USA_AGENCY_atcf', 'LAT', 'USA_STATUS_WV', 'USA_RMW', 'BASIN_nan', 'USA_POCI', 'NATURE_NR', 'USA_ROCI', 'USA_SSHS', 'USA_R34_NW', 'STORM_SPEED', 'USA_STATUS_MD', 'USA_R34_SW', 'BASIN_NI', 'USA_WIND', 'USA_STATUS_SD', 'USA_STATUS_ST', 'USA_STATUS_TC', 'NATURE_ET', 'USA_STATUS_SS', 'BASIN_SP', 'NATURE_SS', 'SEASON', 'USA_AGENCY_jtwc_io', 'NUMBER', 'USA_STATUS_DB', 'USA_STATUS_EX', 'USA_STATUS_LO', 'USA_R34_SE']
#
#   Training random_forest...
#   Training time: 0.19s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9317   0.9437
#   precision      0.0000   0.7778
#   recall         0.0000   0.0262
#   f1_score       0.0000   0.0507
#   auc            0.7301   0.8018
#
#   Training xgboost...
#   Training time: 0.38s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9356   0.9508
#   precision      0.5128   0.6439
#   recall         0.1325   0.3184
#   f1_score       0.2105   0.4261
#   auc            0.8640   0.8603
#
#   Training mlp...
#   Training time: 1.90s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8613   0.8563
#   precision      0.1325   0.1074
#   recall         0.2053   0.2060
#   f1_score       0.1610   0.1412
#   auc            0.6167   0.5930
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: LIME (k=50)
# ────────────────────────────────────────────────────────────
#   Running LIME on 500 samples...
#   LIME progress: 0/500
#   LIME progress: 100/500
#   LIME progress: 200/500
#   LIME progress: 300/500
#   LIME progress: 400/500
# Selected features: 50 / 53
# Feature selection time: 21.46s
# Top features: ['LON', 'USA_STATUS_WV', 'LAT', 'USA_AGENCY_atcf', 'USA_POCI', 'BASIN_nan', 'USA_RMW', 'NATURE_NR', 'USA_STATUS_MD', 'USA_SSHS', 'USA_ROCI', 'USA_R34_NW', 'STORM_SPEED', 'BASIN_NI', 'USA_R34_SW', 'USA_STATUS_SD', 'USA_WIND', 'USA_STATUS_TC', 'USA_STATUS_ST', 'USA_STATUS_SS', 'NATURE_ET', 'NATURE_SS', 'BASIN_SP', 'SEASON', 'USA_AGENCY_jtwc_io', 'NUMBER', 'USA_STATUS_EX', 'USA_STATUS_DB', 'USA_STATUS_LO', 'USA_R34_SE', 'NATURE_MX', 'BASIN_EP', 'BASIN_WP', 'USA_STATUS_HU', 'USA_STATUS_TS', 'STORM_DIR', 'USA_STATUS_TY', 'USA_AGENCY_jtwc_sh', 'USA_AGENCY_hurdat_epa', 'TRACK_TYPE_nan', 'USA_PRES', 'USA_AGENCY_hurdat_atl', 'USA_AGENCY_jtwc_wp', 'NATURE_DS', 'USA_STATUS_TD', 'USA_R34_NE', 'BASIN_SI', 'NATURE_TS', 'USA_STATUS_nan', 'USA_AGENCY_nan']
#
#   Training random_forest...
#   Training time: 0.30s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9351   0.9429
#   precision      0.0000   0.6000
#   recall         0.0000   0.0112
#   f1_score       0.0000   0.0221
#   auc            0.7436   0.8153
#
#   Training xgboost...
#   Training time: 1.02s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9343   0.9504
#   precision      0.4706   0.6364
#   recall         0.1060   0.3146
#   f1_score       0.1730   0.4211
#   auc            0.8615   0.8538
#
#   Training mlp...
#   Training time: 4.24s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8849   0.8578
#   precision      0.1657   0.1624
#   recall         0.1921   0.3558
#   f1_score       0.1779   0.2230
#   auc            0.6447   0.7203
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/xai.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/models/xai
