# %% [markdown]
# ### Run xai methods

# %%
from src.experiments.run_xai_fs import run_xai_fs

# %%
DATASETS = ["ibtracs.last3years"]
all_results = []
for ds in DATASETS:
    results = run_xai_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL XAI FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# XAI-Based Feature Selection: ibtracs.last3years
# ============================================================
#
# Training samples: 18620
#
# Test samples: 4655
# Original features: 61
#
#
# ============================================================
# SHAP VALUES
# ============================================================
#
#
# --- Top 10 features ---
# Selected 10 features
#   logistic_regression  - F1: 0.0000, AUC: 0.6545
#   random_forest        - F1: 0.4173, AUC: 0.8962
#   xgboost              - F1: 0.4804, AUC: 0.9058
#
# --- Top 20 features ---
# Selected 20 features
#   logistic_regression  - F1: 0.0561, AUC: 0.7112
#   random_forest        - F1: 0.2923, AUC: 0.9149
#   xgboost              - F1: 0.2733, AUC: 0.9053
#
# --- Top 30 features ---
# Selected 30 features
#   logistic_regression  - F1: 0.2118, AUC: 0.7586
#   random_forest        - F1: 0.2632, AUC: 0.9125
#   xgboost              - F1: 0.3807, AUC: 0.8860
#
# --- Top 40 features ---
# Selected 40 features
#   logistic_regression  - F1: 0.1941, AUC: 0.7963
#   random_forest        - F1: 0.1818, AUC: 0.9104
#   xgboost              - F1: 0.3579, AUC: 0.8809
#
# --- Top 50 features ---
# Selected 50 features
#   logistic_regression  - F1: 0.2473, AUC: 0.7968
#   random_forest        - F1: 0.1783, AUC: 0.8987
#   xgboost              - F1: 0.3443, AUC: 0.8738
#
# ============================================================
# LIME (Local Interpretable Model-agnostic Explanations)
# ============================================================
#
#
# --- Top 10 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 10 features
#   logistic_regression  - F1: 0.0000, AUC: 0.6277
#   random_forest        - F1: 0.5458, AUC: 0.9454
#   xgboost              - F1: 0.6098, AUC: 0.9469
#
# --- Top 20 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 20 features
#   logistic_regression  - F1: 0.1966, AUC: 0.7514
#   random_forest        - F1: 0.3898, AUC: 0.9090
#   xgboost              - F1: 0.5305, AUC: 0.9357
#
# --- Top 30 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 30 features
#   logistic_regression  - F1: 0.1855, AUC: 0.7772
#   random_forest        - F1: 0.3081, AUC: 0.8860
#   xgboost              - F1: 0.4936, AUC: 0.9145
#
# --- Top 40 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 40 features
#   logistic_regression  - F1: 0.1525, AUC: 0.7817
#   random_forest        - F1: 0.3196, AUC: 0.8821
#   xgboost              - F1: 0.4979, AUC: 0.9167
#
# --- Top 50 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 50 features
#   logistic_regression  - F1: 0.1794, AUC: 0.7929
#   random_forest        - F1: 0.1905, AUC: 0.8669
#   xgboost              - F1: 0.3812, AUC: 0.8884
#
# ============================================================
# XAI FS complete for ibtracs.last3years
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/xai_fs.csv
# ============================================================
#
#
# ============================================================
# ALL XAI FEATURE SELECTION COMPLETE
# ============================================================
