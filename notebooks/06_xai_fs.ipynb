# %% [markdown]
# ### Run xai methods

# %%
from src.experiments.run_xai_fs import run_xai_fs

# %%
DATASETS = ["ibtracs.last3years"]
#DATASETS = ["ibtracs.ALL.list.v04r01"]
all_results = []
for ds in DATASETS:
    results = run_xai_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL XAI FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# XAI-Based Feature Selection: ibtracs.last3years
# ============================================================
#
# Training samples: 18620
#
# Test samples: 4655
# Original features: 61
#
#
# ============================================================
# SHAP VALUES
# ============================================================
#
#
# --- Top 10 features ---
# Selected 10 features
#   logistic_regression  - F1: 0.0000, AUC: 0.6560
#   random_forest        - F1: 0.3762, AUC: 0.9052
#   xgboost              - F1: 0.4550, AUC: 0.8957
#
# --- Top 20 features ---
# Selected 20 features
#   logistic_regression  - F1: 0.2087, AUC: 0.7562
#   random_forest        - F1: 0.2514, AUC: 0.9234
#   xgboost              - F1: 0.3056, AUC: 0.8570
#
# --- Top 30 features ---
# Selected 30 features
#   logistic_regression  - F1: 0.2118, AUC: 0.7586
#   random_forest        - F1: 0.2529, AUC: 0.9097
#   xgboost              - F1: 0.3807, AUC: 0.8860
#
# --- Top 40 features ---
# Selected 40 features
#   logistic_regression  - F1: 0.2216, AUC: 0.7921
#   random_forest        - F1: 0.2067, AUC: 0.9075
#   xgboost              - F1: 0.3164, AUC: 0.8752
#
# --- Top 50 features ---
# Selected 50 features
#   logistic_regression  - F1: 0.2294, AUC: 0.7889
#   random_forest        - F1: 0.1956, AUC: 0.9084
#   xgboost              - F1: 0.3443, AUC: 0.8738
#
# ============================================================
# LIME (Local Interpretable Model-agnostic Explanations)
# ============================================================
#
#
# --- Top 10 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 10 features
#   logistic_regression  - F1: 0.0000, AUC: 0.5890
#   random_forest        - F1: 0.2215, AUC: 0.7666
#   xgboost              - F1: 0.1872, AUC: 0.8450
#
# --- Top 20 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 20 features
#   logistic_regression  - F1: 0.1966, AUC: 0.7517
#   random_forest        - F1: 0.3852, AUC: 0.9041
#   xgboost              - F1: 0.5681, AUC: 0.9267
#
# --- Top 30 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 30 features
#   logistic_regression  - F1: 0.1845, AUC: 0.7751
#   random_forest        - F1: 0.3434, AUC: 0.8825
#   xgboost              - F1: 0.5033, AUC: 0.9200
#
# --- Top 40 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 40 features
#   logistic_regression  - F1: 0.2303, AUC: 0.7928
#   random_forest        - F1: 0.2234, AUC: 0.8976
#   xgboost              - F1: 0.4532, AUC: 0.9124
#
# --- Top 50 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 50 features
#   logistic_regression  - F1: 0.2513, AUC: 0.7900
#   random_forest        - F1: 0.1635, AUC: 0.8924
#   xgboost              - F1: 0.4887, AUC: 0.9164
#
# ============================================================
# XAI FS complete for ibtracs.last3years
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/xai_fs.csv
# ============================================================
#
#
# ============================================================
# ALL XAI FEATURE SELECTION COMPLETE
# ============================================================
