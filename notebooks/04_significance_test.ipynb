# %%
from src.experiments.run_significance_tests import run_friedman_nemenyi

# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
results = run_friedman_nemenyi(ds)
# Out:
# ...
#  Friedman Test + Nemenyi Post-Hoc Analysis
# ...
#
#
# ────────────────────────────────────────────────────────────
#  Metric: F1 SCORE
# ────────────────────────────────────────────────────────────
#
#   Classifier: random_forest
#   Groups: 4, Observations per group: 10
#     baseline: mean=0.1831 ± 0.0116
#     fs_set: mean=0.5623 ± 0.0155
#     op_set: mean=0.5759 ± 0.0322
#     x_set: mean=0.5669 ± 0.0220
#
#   Friedman: chi2=19.1212, p=0.0003 → SIGNIFICANT
#
#   Average ranks (lower = better):
#     baseline: 4.00
#     fs_set: 2.30
#     op_set: 1.80
#     x_set: 1.90
#
#   Nemenyi CD (alpha=0.05): 1.4832
#
#   Pairwise rank differences:
#     baseline vs fs_set: |4.00 - 2.30| = 1.70 > 1.48 → SIGNIFICANT
#     baseline vs op_set: |4.00 - 1.80| = 2.20 > 1.48 → SIGNIFICANT
#     baseline vs x_set: |4.00 - 1.90| = 2.10 > 1.48 → SIGNIFICANT
#     fs_set vs op_set: |2.30 - 1.80| = 0.50 < 1.48 → not significant
#     fs_set vs x_set: |2.30 - 1.90| = 0.40 < 1.48 → not significant
# ...
