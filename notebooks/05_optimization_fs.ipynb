# %% [markdown]
# ### Run optimization methods

# %%
from src.experiments.run_optimization_fs import run_optimization_fs

# %%
ds = "ibtracs.ALL.list.v04r01"
results = run_optimization_fs(ds)
# Out:
# ============================================================
# = Running Optimization-Based Feature Selection for: ibtracs.ALL.list.v04r01
# ============================================================
#
# Training samples:    213577
# Validation samples:  30511
# Test samples:        61022
# Features (original): 63
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: PSO (k=10)
# ────────────────────────────────────────────────────────────
#   PSO best val AUC: 0.9664
# Selected features: 10 / 63
# Feature selection time: 268.69s
# Features: ['LON', 'TRACK_TYPE_main', 'USA_AGENCY_jtwc_wp', 'WMO_AGENCY_atcf', 'USA_STATUS_ET', 'USA_STATUS_WV', 'BASIN_SI', 'USA_STATUS_ST', 'USA_LON', 'LAT']
#
#   Training random_forest...
#   Training time: 1.62s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9499   0.9378
#   precision      0.8779   0.8954
#   recall         0.4370   0.4416
#   f1_score       0.5835   0.5915
#   auc            0.9709   0.9698
#
#   Training xgboost...
#   Training time: 0.44s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9495   0.9391
#   precision      0.8583   0.8674
#   recall         0.4447   0.4761
#   f1_score       0.5859   0.6148
#   auc            0.9664   0.9597
#
#   Training mlp...
#   Training time: 7.20s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9402   0.9182
#   precision      0.7624   0.6909
#   recall         0.3705   0.3579
#   f1_score       0.4986   0.4715
#   auc            0.9175   0.9030
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: PSO (k=30)
# ────────────────────────────────────────────────────────────
#   PSO best val AUC: 0.9676
# Selected features: 30 / 63
# Feature selection time: 406.65s
# Features: ['USA_STATUS_nan', 'USA_AGENCY_nan', 'WMO_AGENCY_hurdat_epa', 'BASIN_EP', 'USA_PRES', 'TRACK_TYPE_main', 'STORM_SPEED', 'USA_LON', 'USA_AGENCY_hurdat_epa', 'USA_STATUS_TS', 'NUMBER', 'LON', 'USA_STATUS_EX', 'NATURE_TS', 'USA_STATUS_TD', 'BASIN_SA', 'WMO_AGENCY_atcf', 'BASIN_SI', 'TRACK_TYPE_nan', 'USA_LAT', 'NATURE_ET', 'USA_AGENCY_jtwc_sh', 'NATURE_MX', 'USA_STATUS_XX', 'USA_STATUS_HU', 'BASIN_WP', 'USA_AGENCY_jtwc_wp', 'WMO_AGENCY_tokyo', 'USA_AGENCY_jtwc_cp', 'LAT']
#
#   Training random_forest...
#   Training time: 1.80s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9331   0.9177
#   precision      0.8700   0.9035
#   recall         0.1967   0.2167
#   f1_score       0.3208   0.3496
#   auc            0.9566   0.9514
#
#   Training xgboost...
#   Training time: 0.64s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9496   0.9364
#   precision      0.8487   0.8690
#   recall         0.4533   0.4432
#   f1_score       0.5910   0.5870
#   auc            0.9676   0.9578
#
#   Training mlp...
#   Training time: 10.42s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9413   0.9233
#   precision      0.7361   0.7423
#   recall         0.4198   0.3804
#   f1_score       0.5347   0.5030
#   auc            0.9216   0.8947
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: PSO (k=50)
# ────────────────────────────────────────────────────────────
#   PSO best val AUC: 0.9676
# Selected features: 50 / 63
# Feature selection time: 534.32s
# Features: ['USA_STATUS_DB', 'TRACK_TYPE_nan', 'USA_STATUS_TD', 'USA_AGENCY_hurdat_epa', 'USA_AGENCY_jtwc_io', 'WMO_AGENCY_tokyo', 'WMO_AGENCY_bom', 'USA_LAT', 'NATURE_NR', 'USA_AGENCY_atcf', 'USA_AGENCY_jtwc_ep', 'NUMBER', 'USA_STATUS_ET', 'LAT', 'WMO_AGENCY_hurdat_epa', 'USA_AGENCY_cphc', 'BASIN_NI', 'USA_STATUS_HU', 'STORM_DIR', 'USA_STATUS_TC', 'WMO_AGENCY_hurdat_atl', 'USA_AGENCY_jtwc_wp', 'USA_STATUS_SS', 'WMO_PRES', 'WMO_AGENCY_newdelhi', 'USA_STATUS_HR', 'LON', 'BASIN_SI', 'BASIN_SP', 'USA_STATUS_TY', 'USA_STATUS_WV', 'USA_STATUS_LO', 'NATURE_ET', 'USA_AGENCY_hurdat_atl', 'NATURE_TS', 'USA_STATUS_EX', 'WMO_AGENCY_nan', 'NATURE_MX', 'STORM_SPEED', 'USA_AGENCY_jtwc_cp', 'USA_AGENCY_jtwc_sh', 'WMO_AGENCY_nadi', 'USA_STATUS_ST', 'USA_STATUS_SD', 'USA_LON', 'BASIN_SA', 'WMO_AGENCY_atcf', 'NATURE_SS', 'WMO_AGENCY_wellington', 'BASIN_WP']
#
#   Training random_forest...
#   Training time: 2.48s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9277   0.9112
#   precision      0.8289   0.9087
#   recall         0.1265   0.1439
#   f1_score       0.2195   0.2485
#   auc            0.9508   0.9453
#
#   Training xgboost...
#   Training time: 0.88s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9491   0.9363
#   precision      0.8481   0.8738
#   recall         0.4463   0.4384
#   f1_score       0.5849   0.5839
#   auc            0.9676   0.9579
#
#   Training mlp...
#   Training time: 6.67s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9399   0.9192
#   precision      0.7040   0.6753
#   recall         0.4337   0.4010
#   f1_score       0.5367   0.5032
#   auc            0.9190   0.8929
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: DIFFERENTIAL EVOLUTION (k=10)
# ────────────────────────────────────────────────────────────
# differential_evolution step 1: f(x)= 0.03444392487625603
# differential_evolution step 2: f(x)= 0.03444392487625603
# differential_evolution step 3: f(x)= 0.03419925769603105
# differential_evolution step 4: f(x)= 0.03419925769603105
# differential_evolution step 5: f(x)= 0.034177272982386375
# differential_evolution step 6: f(x)= 0.034177272982386375
# differential_evolution step 7: f(x)= 0.034177272982386375
# differential_evolution step 8: f(x)= 0.034177272982386375
# differential_evolution step 9: f(x)= 0.03353600127720724
# differential_evolution step 10: f(x)= 0.03338907301571237
# differential_evolution step 11: f(x)= 0.03240530070057379
# differential_evolution step 12: f(x)= 0.03240530070057379
# differential_evolution step 13: f(x)= 0.03209049181491097
# differential_evolution step 14: f(x)= 0.03209049181491097
# differential_evolution step 15: f(x)= 0.03209049181491097
# differential_evolution step 16: f(x)= 0.03209049181491097
# differential_evolution step 17: f(x)= 0.03209049181491097
# differential_evolution step 18: f(x)= 0.03209049181491097
# differential_evolution step 19: f(x)= 0.03209049181491097
# differential_evolution step 20: f(x)= 0.03209049181491097
#   DE best val AUC: 0.9679
# Selected features: 10 / 63
# Feature selection time: 635.39s
# Features: ['LAT', 'WMO_AGENCY_hurdat_epa', 'LON', 'WMO_PRES', 'USA_AGENCY_jtwc_cp', 'BASIN_SI', 'TRACK_TYPE_main', 'USA_LAT', 'USA_LON', 'WMO_AGENCY_tokyo']
#
#   Training random_forest...
#   Training time: 2.07s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9505   0.9423
#   precision      0.8661   0.8877
#   recall         0.4541   0.4977
#   f1_score       0.5958   0.6378
#   auc            0.9748   0.9745
#
#   Training xgboost...
#   Training time: 0.49s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9510   0.9388
#   precision      0.8626   0.8683
#   recall         0.4635   0.4712
#   f1_score       0.6030   0.6109
#   auc            0.9679   0.9621
#
#   Training mlp...
#   Training time: 10.42s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9454   0.9321
#   precision      0.7703   0.7946
#   recall         0.4570   0.4504
#   f1_score       0.5736   0.5749
#   auc            0.9293   0.9109
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: DIFFERENTIAL EVOLUTION (k=30)
# ────────────────────────────────────────────────────────────
# differential_evolution step 1: f(x)= 0.032944013425797114
# differential_evolution step 2: f(x)= 0.03262558404165694
# differential_evolution step 3: f(x)= 0.0324271327425959
# differential_evolution step 4: f(x)= 0.03222140409619412
# differential_evolution step 5: f(x)= 0.03222140409619412
# differential_evolution step 6: f(x)= 0.03222140409619412
# differential_evolution step 7: f(x)= 0.03222140409619412
# differential_evolution step 8: f(x)= 0.032089910208729755
# differential_evolution step 9: f(x)= 0.032089910208729755
# differential_evolution step 10: f(x)= 0.03189030296738382
# differential_evolution step 11: f(x)= 0.03189030296738382
# differential_evolution step 12: f(x)= 0.03189030296738382
# differential_evolution step 13: f(x)= 0.03189030296738382
# differential_evolution step 14: f(x)= 0.031609677985013795
# differential_evolution step 15: f(x)= 0.031609677985013795
# differential_evolution step 16: f(x)= 0.031609677985013795
# differential_evolution step 17: f(x)= 0.031609677985013795
# differential_evolution step 18: f(x)= 0.031609677985013795
# differential_evolution step 19: f(x)= 0.031609677985013795
# differential_evolution step 20: f(x)= 0.031082909996734354
#   DE best val AUC: 0.9689
# Selected features: 30 / 63
# Feature selection time: 877.10s
# Features: ['USA_SSHS', 'USA_AGENCY_jtwc_io', 'USA_STATUS_ST', 'BASIN_SA', 'STORM_SPEED', 'USA_STATUS_TC', 'TRACK_TYPE_nan', 'USA_STATUS_EX', 'TRACK_TYPE_main', 'LON', 'USA_STATUS_TD', 'WMO_AGENCY_wellington', 'USA_PRES', 'USA_LAT', 'USA_STATUS_TY', 'USA_AGENCY_atcf', 'BASIN_SI', 'BASIN_SP', 'WMO_AGENCY_hurdat_epa', 'WMO_AGENCY_nan', 'NATURE_MX', 'USA_STATUS_TS', 'BASIN_NI', 'USA_AGENCY_hurdat_atl', 'WMO_AGENCY_hurdat_atl', 'NATURE_ET', 'NATURE_SS', 'USA_LON', 'USA_STATUS_SS', 'LAT']
#
#   Training random_forest...
#   Training time: 1.71s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9317   0.9172
#   precision      0.8492   0.8944
#   recall         0.1816   0.2137
#   f1_score       0.2992   0.3449
#   auc            0.9552   0.9487
#
#   Training xgboost...
#   Training time: 0.63s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9503   0.9373
#   precision      0.8518   0.8738
#   recall         0.4619   0.4503
#   f1_score       0.5989   0.5943
#   auc            0.9689   0.9588
#
#   Training mlp...
#   Training time: 12.15s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9443   0.9291
#   precision      0.7873   0.7876
#   recall         0.4198   0.4170
#   f1_score       0.5476   0.5453
#   auc            0.9309   0.9176
#
#
# ────────────────────────────────────────────────────────────
# Feature Selection: DIFFERENTIAL EVOLUTION (k=50)
# ────────────────────────────────────────────────────────────
# differential_evolution step 1: f(x)= 0.03240564966428239
# differential_evolution step 2: f(x)= 0.03240564966428239
# differential_evolution step 3: f(x)= 0.03240564966428239
# differential_evolution step 4: f(x)= 0.03240564966428239
# differential_evolution step 5: f(x)= 0.03165217885669591
# differential_evolution step 6: f(x)= 0.03165217885669591
# differential_evolution step 7: f(x)= 0.03165217885669591
# differential_evolution step 8: f(x)= 0.03165217885669591
# differential_evolution step 9: f(x)= 0.03165217885669591
# differential_evolution step 10: f(x)= 0.03165217885669591
# differential_evolution step 11: f(x)= 0.03165217885669591
# differential_evolution step 12: f(x)= 0.03165217885669591
# differential_evolution step 13: f(x)= 0.03165217885669591
# differential_evolution step 14: f(x)= 0.03165217885669591
# differential_evolution step 15: f(x)= 0.03165217885669591
# differential_evolution step 16: f(x)= 0.03165217885669591
# differential_evolution step 17: f(x)= 0.03165217885669591
# differential_evolution step 18: f(x)= 0.03165217885669591
# differential_evolution step 19: f(x)= 0.03109667225299395
# differential_evolution step 20: f(x)= 0.03109667225299395
#   DE best val AUC: 0.9689
# Selected features: 50 / 63
# Feature selection time: 1239.31s
# Features: ['LON', 'NATURE_MX', 'WMO_AGENCY_bom', 'USA_AGENCY_jtwc_ep', 'USA_AGENCY_jtwc_io', 'USA_AGENCY_nan', 'BASIN_EP', 'USA_STATUS_DB', 'USA_STATUS_WV', 'WMO_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'NATURE_TS', 'BASIN_WP', 'LAT', 'USA_STATUS_TD', 'USA_AGENCY_hurdat_epa', 'NATURE_NR', 'WMO_AGENCY_nan', 'USA_STATUS_EX', 'NATURE_ET', 'WMO_AGENCY_newdelhi', 'USA_STATUS_HU', 'STORM_SPEED', 'USA_STATUS_TC', 'TRACK_TYPE_main', 'TRACK_TYPE_nan', 'WMO_AGENCY_hurdat_atl', 'WMO_AGENCY_tokyo', 'WMO_AGENCY_hurdat_epa', 'NATURE_SS', 'USA_AGENCY_hurdat_atl', 'BASIN_SP', 'USA_LAT', 'BASIN_SA', 'USA_STATUS_nan', 'WMO_AGENCY_reunion', 'USA_STATUS_TY', 'USA_STATUS_ET', 'USA_AGENCY_jtwc_sh', 'USA_STATUS_TS', 'USA_STATUS_SD', 'BASIN_SI', 'BASIN_nan', 'USA_AGENCY_atcf', 'USA_STATUS_SS', 'USA_AGENCY_cphc', 'BASIN_NI', 'USA_STATUS_HR', 'USA_LON', 'USA_STATUS_LO']
#
#   Training random_forest...
#   Training time: 2.00s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9291   0.9143
#   precision      0.8429   0.9127
#   recall         0.1444   0.1764
#   f1_score       0.2466   0.2956
#   auc            0.9557   0.9464
#
#   Training xgboost...
#   Training time: 0.82s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9500   0.9373
#   precision      0.8616   0.8745
#   recall         0.4496   0.4501
#   f1_score       0.5909   0.5943
#   auc            0.9689   0.9594
#
#   Training mlp...
#   Training time: 9.88s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9426   0.9290
#   precision      0.7046   0.7396
#   recall         0.4925   0.4686
#   f1_score       0.5797   0.5737
#   auc            0.9359   0.9126
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/optimization.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/optimization

# %%
ds = "ibtracs.last3years"
results = run_optimization_fs(ds)
