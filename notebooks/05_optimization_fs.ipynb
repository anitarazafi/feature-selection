# %% [markdown]
# ### Run optimization methods

# %%
from src.experiments.run_optimization_fs import run_optimization_fs

# %%
DATASETS = ["ibtracs.last3years"]
#DATASETS = ["ibtracs.ALL.list.v04r01"]
all_results = []
for ds in DATASETS:
    results = run_optimization_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL OPTIMIZATION FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# Optimization-Based Feature Selection: ibtracs.last3years
# ============================================================
#
# Training samples: 18620
# Test samples: 4655
# Original features: 61
#
#
# ============================================================
# PARTICLE SWARM OPTIMIZATION (PSO)
# ============================================================
#
#
# --- Selecting 10 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.0925
#     Iteration 5: Best F1 = 0.1307
#     Iteration 10: Best F1 = 0.1324
#     Iteration 15: Best F1 = 0.1341
#     Final best F1: 0.1341
#   Selection completed in 83.90s
#   logistic_regression  - F1: 0.1180, AUC: 0.6986
#   random_forest        - F1: 0.0718, AUC: 0.5948
#   xgboost              - F1: 0.0453, AUC: 0.5787
#
# --- Selecting 20 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.1206
#     Iteration 5: Best F1 = 0.1821
#     Iteration 10: Best F1 = 0.2007
#     Iteration 15: Best F1 = 0.2014
#     Final best F1: 0.2014
#   Selection completed in 79.83s
#   logistic_regression  - F1: 0.1006, AUC: 0.7090
#   random_forest        - F1: 0.1180, AUC: 0.7044
#   xgboost              - F1: 0.0972, AUC: 0.6912
#
# --- Selecting 30 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.1530
#     Iteration 5: Best F1 = 0.2263
#     Iteration 10: Best F1 = 0.2292
#     Iteration 15: Best F1 = 0.2341
#     Final best F1: 0.2360
#   Selection completed in 84.84s
#   logistic_regression  - F1: 0.1049, AUC: 0.7289
#   random_forest        - F1: 0.0213, AUC: 0.6947
#   xgboost              - F1: 0.1143, AUC: 0.5726
#
# ============================================================
# DIFFERENTIAL EVOLUTION (DE)
# ============================================================
#
#
# --- Selecting 10 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.0808
#     Generation 5: Best F1 = 0.0920
#     Generation 10: Best F1 = 0.1126
#     Generation 15: Best F1 = 0.1181
#     Final best F1: 0.1181
#   Selection completed in 82.35s
#   logistic_regression  - F1: 0.1169, AUC: 0.6396
#   random_forest        - F1: 0.1496, AUC: 0.5884
#   xgboost              - F1: 0.0950, AUC: 0.5797
#
# --- Selecting 20 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.1610
#     Generation 5: Best F1 = 0.1662
#     Generation 10: Best F1 = 0.1705
#     Generation 15: Best F1 = 0.1722
#     Final best F1: 0.1863
#   Selection completed in 92.70s
#   logistic_regression  - F1: 0.1203, AUC: 0.7574
#   random_forest        - F1: 0.2103, AUC: 0.8053
#   xgboost              - F1: 0.2444, AUC: 0.8209
#
# --- Selecting 30 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.2008
#     Generation 5: Best F1 = 0.2008
#     Generation 10: Best F1 = 0.2083
#     Generation 15: Best F1 = 0.2083
#     Final best F1: 0.2272
#   Selection completed in 95.99s
#   logistic_regression  - F1: 0.1053, AUC: 0.7102
#   random_forest        - F1: 0.0458, AUC: 0.8722
#   xgboost              - F1: 0.4680, AUC: 0.9097
#
# ============================================================
# Optimization FS complete for ibtracs.last3years
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/optimization_fs.csv
# ============================================================
#
#
# ============================================================
# ALL OPTIMIZATION FEATURE SELECTION COMPLETE
# ============================================================
