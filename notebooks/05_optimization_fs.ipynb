# %% [markdown]
# ### Run optimization methods

# %%
from src.experiments.run_optimization_fs import run_optimization_fs

# %%
DATASETS = ["ibtracs.last3years"]
all_results = []
for ds in DATASETS:
    results = run_optimization_fs(ds)
    all_results.append(results)
print("\n" + "="*60)
print("ALL OPTIMIZATION FEATURE SELECTION COMPLETE")
print("="*60)
# Out:
# ============================================================
# Optimization-Based Feature Selection: ibtracs.last3years
# ============================================================
#
# Training samples: 18620
# Test samples: 4655
# Original features: 61
#
#
# ============================================================
# PARTICLE SWARM OPTIMIZATION (PSO)
# ============================================================
#
#
# --- Selecting 10 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.0927
#     Iteration 5: Best F1 = 0.1318
#     Iteration 10: Best F1 = 0.1336
#     Iteration 15: Best F1 = 0.1361
#     Final best F1: 0.1368
#   Selection completed in 99.78s
#   logistic_regression  - F1: 0.0291, AUC: 0.6461
#   random_forest        - F1: 0.1189, AUC: 0.5746
#   xgboost              - F1: 0.1390, AUC: 0.6382
#
# --- Selecting 20 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.1336
#     Iteration 5: Best F1 = 0.1486
#     Iteration 10: Best F1 = 0.1537
#     Iteration 15: Best F1 = 0.1554
#     Final best F1: 0.1556
#   Selection completed in 101.34s
#   logistic_regression  - F1: 0.1592, AUC: 0.6960
#   random_forest        - F1: 0.0664, AUC: 0.6812
#   xgboost              - F1: 0.1707, AUC: 0.7272
#
# --- Selecting 30 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.1635
#     Iteration 5: Best F1 = 0.2636
#     Iteration 10: Best F1 = 0.2740
#     Iteration 15: Best F1 = 0.2740
#     Final best F1: 0.2740
#   Selection completed in 106.27s
#   logistic_regression  - F1: 0.2289, AUC: 0.7919
#   random_forest        - F1: 0.1302, AUC: 0.8114
#   xgboost              - F1: 0.2705, AUC: 0.8432
#
# ============================================================
# DIFFERENTIAL EVOLUTION (DE)
# ============================================================
#
#
# --- Selecting 10 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.0728
#     Generation 5: Best F1 = 0.1123
#     Generation 10: Best F1 = 0.1267
#     Generation 15: Best F1 = 0.1267
#     Final best F1: 0.1308
#   Selection completed in 104.85s
#   logistic_regression  - F1: 0.0000, AUC: 0.6667
#   random_forest        - F1: 0.1266, AUC: 0.6848
#   xgboost              - F1: 0.1918, AUC: 0.7611
#
# --- Selecting 20 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.1254
#     Generation 5: Best F1 = 0.1284
#     Generation 10: Best F1 = 0.1308
#     Generation 15: Best F1 = 0.1540
#     Final best F1: 0.1572
#   Selection completed in 114.03s
#   logistic_regression  - F1: 0.0074, AUC: 0.7624
#   random_forest        - F1: 0.1494, AUC: 0.7694
#   xgboost              - F1: 0.1658, AUC: 0.8116
#
# --- Selecting 30 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.1786
#     Generation 5: Best F1 = 0.2177
#     Generation 10: Best F1 = 0.2177
#     Generation 15: Best F1 = 0.2285
#     Final best F1: 0.2285
#   Selection completed in 118.07s
#   logistic_regression  - F1: 0.1053, AUC: 0.7394
#   random_forest        - F1: 0.0209, AUC: 0.6562
#   xgboost              - F1: 0.0734, AUC: 0.5640
#
# ============================================================
# Optimization FS complete for ibtracs.last3years
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/optimization_fs.csv
# ============================================================
#
#
# ============================================================
# ALL OPTIMIZATION FEATURE SELECTION COMPLETE
# ============================================================
