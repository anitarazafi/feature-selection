# %%
from src.analysis.best_results import generate_comparison_table
from src.visualization.curves_grid import plot_roc_curves

# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
generate_comparison_table(ds)
# Out:
# Saved comparison table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/comparison_summary.tex
#
# Summary:
#   Baseline (63 feat.): best F1=0.5873, best AUC=0.9547
#   FS-Set (12 feat.): best F1=0.6063, best AUC=0.9673
#   Op-Set (11 feat.): best F1=0.6018, best AUC=0.9703
#   X-Set (12 feat.): best F1=0.5800, best AUC=0.9712
#
#   Best F1:  FS-Set (0.6063)
#   Best AUC: X-Set (0.9712)
# '\\begin{table}[htbp]\n\\centering\n\\caption{Best Test-Set Results per Paradigm (across all classifiers)}\n\\label{tab:comparison_summary}\n\\begin{tabular}{lcccc}\n\\toprule\n & Baseline & FS-Set & Op-Set & X-Set \\\\\n & (63) & (12) & (11) & (12) \\\\\n\\midrule\nBest F1 & 0.5873 & \\textbf{0.6063} & 0.6018 & 0.5800 \\\\\nBest AUC & 0.9547 & 0.9673 & 0.9703 & \\textbf{0.9712} \\\\\n\\bottomrule\n\\end{tabular}\n\\end{table}'

# %%
plot_roc_curves(ds)
# Out:
# ...
#  Generating ROC Curves for: ibtracs.ALL.list.v04r01
# ...
# Saved ROC curve grid to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/roc_curves.png
