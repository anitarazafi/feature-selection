# %%
from src.visualization.curves import plot_roc_curves

# %%
ds = "ibtracs.ALL.list.v04r01"
plot_roc_curves(ds)
# Out:
# ...
#  Generating ROC Curves for: ibtracs.ALL.list.v04r01
# ...
#   Saved ROC curve for Random Forest
#   Saved ROC curve for XGBoost
#   Saved ROC curve for MLP
#
# All ROC curves saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots

# %%
from src.visualization.curves_grid import plot_roc_curves

# %%
ds = "ibtracs.ALL.list.v04r01"
plot_roc_curves(ds)
# Out:
# ...
#  Generating ROC Curves for: ibtracs.ALL.list.v04r01
# ...
# Saved ROC curve grid to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/roc_curves.png
