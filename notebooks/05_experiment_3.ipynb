# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
from src.experiments_new.run_significance_tests import run_friedman_nemenyi
results = run_friedman_nemenyi(ds)
# Out:
# ============================================================
#  Friedman Test + Nemenyi Post-Hoc Analysis
# ============================================================
#
# Detected methods: ['baseline', 'fs_set_intersection', 'fs_set_union', 'fs_set_weighted', 'op_set_intersection', 'op_set_union', 'op_set_weighted', 'x_set_intersection', 'x_set_union', 'x_set_weighted']
# Detected classifiers: ['mlp', 'random_forest', 'xgboost']
# Number of seeds: 10
#
# ============================================================
#  Metric: F1 SCORE
# ============================================================
#
#   Classifier: mlp
#   Groups: 10, Observations per group: 10
#     baseline: mean=0.5466 ± 0.0214
#     fs_set_intersection: mean=0.4409 ± 0.2221
#     fs_set_union: mean=0.5310 ± 0.0277
#     fs_set_weighted: mean=0.5527 ± 0.0341
#     op_set_intersection: mean=0.5484 ± 0.0216
#     op_set_union: mean=0.5330 ± 0.0308
#     op_set_weighted: mean=0.5373 ± 0.0192
#     x_set_intersection: mean=0.5487 ± 0.0447
#     x_set_union: mean=0.5833 ± 0.0170
#     x_set_weighted: mean=0.5570 ± 0.0377
#
#   Friedman: chi2=19.3309, p=0.0225 → SIGNIFICANT
#
#   Average ranks (lower = better):
#     baseline: 5.60
#     fs_set_intersection: 6.30
#     fs_set_union: 7.30
#     fs_set_weighted: 4.80
#     op_set_intersection: 5.40
#     op_set_union: 6.70
#     op_set_weighted: 6.50
#     x_set_intersection: 5.40
#     x_set_union: 2.30
#     x_set_weighted: 4.70
#
#   Nemenyi CD (alpha=0.05): 4.2841
#
#   Pairwise rank differences (showing only significant):
#     fs_set_union vs x_set_union: |7.30 - 2.30| = 5.00 > 4.28 → x_set_union is better
#     op_set_union vs x_set_union: |6.70 - 2.30| = 4.40 > 4.28 → x_set_union is better
#
#     Total significant pairs: 2 / 45
#
#   Classifier: random_forest
#   Groups: 10, Observations per group: 10
#     baseline: mean=0.1831 ± 0.0116
#     fs_set_intersection: mean=0.5614 ± 0.2274
#     fs_set_union: mean=0.5623 ± 0.0155
#     fs_set_weighted: mean=0.6040 ± 0.0119
#     op_set_intersection: mean=0.6670 ± 0.0393
#     op_set_union: mean=0.4432 ± 0.0589
#     op_set_weighted: mean=0.4871 ± 0.0598
#     x_set_intersection: mean=0.6993 ± 0.0162
#     x_set_union: mean=0.5375 ± 0.0093
#     x_set_weighted: mean=0.4251 ± 0.0855
#
#   Friedman: chi2=74.0073, p=0.0000 → SIGNIFICANT
#
#   Average ranks (lower = better):
#     baseline: 9.80
#     fs_set_intersection: 4.00
#     fs_set_union: 5.00
#     fs_set_weighted: 3.70
#     op_set_intersection: 2.20
#     op_set_union: 7.80
#     op_set_weighted: 7.00
#     x_set_intersection: 1.30
#     x_set_union: 6.00
#     x_set_weighted: 8.20
#
#   Nemenyi CD (alpha=0.05): 4.2841
#
#   Pairwise rank differences (showing only significant):
#     baseline vs fs_set_intersection: |9.80 - 4.00| = 5.80 > 4.28 → fs_set_intersection is better
#     baseline vs fs_set_union: |9.80 - 5.00| = 4.80 > 4.28 → fs_set_union is better
#     baseline vs fs_set_weighted: |9.80 - 3.70| = 6.10 > 4.28 → fs_set_weighted is better
#     baseline vs op_set_intersection: |9.80 - 2.20| = 7.60 > 4.28 → op_set_intersection is better
#     baseline vs x_set_intersection: |9.80 - 1.30| = 8.50 > 4.28 → x_set_intersection is better
#     fs_set_weighted vs x_set_weighted: |3.70 - 8.20| = 4.50 > 4.28 → fs_set_weighted is better
#     op_set_intersection vs op_set_union: |2.20 - 7.80| = 5.60 > 4.28 → op_set_intersection is better
#     op_set_intersection vs op_set_weighted: |2.20 - 7.00| = 4.80 > 4.28 → op_set_intersection is better
#     op_set_intersection vs x_set_weighted: |2.20 - 8.20| = 6.00 > 4.28 → op_set_intersection is better
#     op_set_union vs x_set_intersection: |7.80 - 1.30| = 6.50 > 4.28 → x_set_intersection is better
#     op_set_weighted vs x_set_intersection: |7.00 - 1.30| = 5.70 > 4.28 → x_set_intersection is better
#     x_set_intersection vs x_set_union: |1.30 - 6.00| = 4.70 > 4.28 → x_set_intersection is better
#     x_set_intersection vs x_set_weighted: |1.30 - 8.20| = 6.90 > 4.28 → x_set_intersection is better
#
#     Total significant pairs: 13 / 45
#
#   Classifier: xgboost
#   Groups: 10, Observations per group: 10
#     baseline: mean=0.5897 ± 0.0058
#     fs_set_intersection: mean=0.4842 ± 0.2424
#     fs_set_union: mean=0.6018 ± 0.0104
#     fs_set_weighted: mean=0.5959 ± 0.0069
#     op_set_intersection: mean=0.5976 ± 0.0268
#     op_set_union: mean=0.6009 ± 0.0147
#     op_set_weighted: mean=0.5968 ± 0.0195
#     x_set_intersection: mean=0.3162 ± 0.1787
#     x_set_union: mean=0.5897 ± 0.0073
#     x_set_weighted: mean=0.5569 ± 0.0156
#
#   Friedman: chi2=45.4691, p=0.0000 → SIGNIFICANT
#
#   Average ranks (lower = better):
#     baseline: 6.00
#     fs_set_intersection: 4.50
#     fs_set_union: 3.30
#     fs_set_weighted: 4.70
#     op_set_intersection: 4.50
#     op_set_union: 3.50
#     op_set_weighted: 4.20
#     x_set_intersection: 9.80
#     x_set_union: 5.90
#     x_set_weighted: 8.60
#
#   Nemenyi CD (alpha=0.05): 4.2841
#
#   Pairwise rank differences (showing only significant):
#     fs_set_intersection vs x_set_intersection: |4.50 - 9.80| = 5.30 > 4.28 → fs_set_intersection is better
#     fs_set_union vs x_set_intersection: |3.30 - 9.80| = 6.50 > 4.28 → fs_set_union is better
#     fs_set_union vs x_set_weighted: |3.30 - 8.60| = 5.30 > 4.28 → fs_set_union is better
#     fs_set_weighted vs x_set_intersection: |4.70 - 9.80| = 5.10 > 4.28 → fs_set_weighted is better
#     op_set_intersection vs x_set_intersection: |4.50 - 9.80| = 5.30 > 4.28 → op_set_intersection is better
#     op_set_union vs x_set_intersection: |3.50 - 9.80| = 6.30 > 4.28 → op_set_union is better
#     op_set_union vs x_set_weighted: |3.50 - 8.60| = 5.10 > 4.28 → op_set_union is better
#     op_set_weighted vs x_set_intersection: |4.20 - 9.80| = 5.60 > 4.28 → op_set_weighted is better
#     op_set_weighted vs x_set_weighted: |4.20 - 8.60| = 4.40 > 4.28 → op_set_weighted is better
#
#     Total significant pairs: 9 / 45
#
# ============================================================
#  Metric: AUC
# ============================================================
#
#   Classifier: mlp
#   Groups: 10, Observations per group: 10
#     baseline: mean=0.9061 ± 0.0055
#     fs_set_intersection: mean=0.8650 ± 0.1083
#     fs_set_union: mean=0.9211 ± 0.0061
#     fs_set_weighted: mean=0.9215 ± 0.0094
#     op_set_intersection: mean=0.9196 ± 0.0065
#     op_set_union: mean=0.9049 ± 0.0096
#     op_set_weighted: mean=0.9102 ± 0.0075
#     x_set_intersection: mean=0.9180 ± 0.0085
#     x_set_union: mean=0.9295 ± 0.0036
#     x_set_weighted: mean=0.9183 ± 0.0092
#
#   Friedman: chi2=44.2359, p=0.0000 → SIGNIFICANT
#
#   Average ranks (lower = better):
#     baseline: 8.70
#     fs_set_intersection: 6.10
#     fs_set_union: 4.45
#     fs_set_weighted: 4.00
#     op_set_intersection: 4.40
#     op_set_union: 8.20
#     op_set_weighted: 7.30
#     x_set_intersection: 5.20
#     x_set_union: 1.70
#     x_set_weighted: 4.95
#
#   Nemenyi CD (alpha=0.05): 4.2841
#
#   Pairwise rank differences (showing only significant):
#     baseline vs fs_set_weighted: |8.70 - 4.00| = 4.70 > 4.28 → fs_set_weighted is better
#     baseline vs op_set_intersection: |8.70 - 4.40| = 4.30 > 4.28 → op_set_intersection is better
#     baseline vs x_set_union: |8.70 - 1.70| = 7.00 > 4.28 → x_set_union is better
#     fs_set_intersection vs x_set_union: |6.10 - 1.70| = 4.40 > 4.28 → x_set_union is better
#     op_set_union vs x_set_union: |8.20 - 1.70| = 6.50 > 4.28 → x_set_union is better
#     op_set_weighted vs x_set_union: |7.30 - 1.70| = 5.60 > 4.28 → x_set_union is better
#
#     Total significant pairs: 6 / 45
#
#   Classifier: random_forest
#   Groups: 10, Observations per group: 10
#     baseline: mean=0.9321 ± 0.0015
#     fs_set_intersection: mean=0.9489 ± 0.0587
#     fs_set_union: mean=0.9685 ± 0.0015
#     fs_set_weighted: mean=0.9721 ± 0.0014
#     op_set_intersection: mean=0.9774 ± 0.0038
#     op_set_union: mean=0.9569 ± 0.0043
#     op_set_weighted: mean=0.9578 ± 0.0065
#     x_set_intersection: mean=0.9822 ± 0.0011
#     x_set_union: mean=0.9683 ± 0.0019
#     x_set_weighted: mean=0.9551 ± 0.0073
#
#   Friedman: chi2=75.4691, p=0.0000 → SIGNIFICANT
#
#   Average ranks (lower = better):
#     baseline: 9.80
#     fs_set_intersection: 4.10
#     fs_set_union: 5.50
#     fs_set_weighted: 3.70
#     op_set_intersection: 2.40
#     op_set_union: 7.80
#     op_set_weighted: 7.50
#     x_set_intersection: 1.00
#     x_set_union: 5.20
#     x_set_weighted: 8.00
#
#   Nemenyi CD (alpha=0.05): 4.2841
#
#   Pairwise rank differences (showing only significant):
#     baseline vs fs_set_intersection: |9.80 - 4.10| = 5.70 > 4.28 → fs_set_intersection is better
#     baseline vs fs_set_union: |9.80 - 5.50| = 4.30 > 4.28 → fs_set_union is better
#     baseline vs fs_set_weighted: |9.80 - 3.70| = 6.10 > 4.28 → fs_set_weighted is better
#     baseline vs op_set_intersection: |9.80 - 2.40| = 7.40 > 4.28 → op_set_intersection is better
#     baseline vs x_set_intersection: |9.80 - 1.00| = 8.80 > 4.28 → x_set_intersection is better
#     baseline vs x_set_union: |9.80 - 5.20| = 4.60 > 4.28 → x_set_union is better
#     fs_set_union vs x_set_intersection: |5.50 - 1.00| = 4.50 > 4.28 → x_set_intersection is better
#     fs_set_weighted vs x_set_weighted: |3.70 - 8.00| = 4.30 > 4.28 → fs_set_weighted is better
#     op_set_intersection vs op_set_union: |2.40 - 7.80| = 5.40 > 4.28 → op_set_intersection is better
#     op_set_intersection vs op_set_weighted: |2.40 - 7.50| = 5.10 > 4.28 → op_set_intersection is better
#     op_set_intersection vs x_set_weighted: |2.40 - 8.00| = 5.60 > 4.28 → op_set_intersection is better
#     op_set_union vs x_set_intersection: |7.80 - 1.00| = 6.80 > 4.28 → x_set_intersection is better
#     op_set_weighted vs x_set_intersection: |7.50 - 1.00| = 6.50 > 4.28 → x_set_intersection is better
#     x_set_intersection vs x_set_weighted: |1.00 - 8.00| = 7.00 > 4.28 → x_set_intersection is better
#
#     Total significant pairs: 14 / 45
#
#   Classifier: xgboost
#   Groups: 10, Observations per group: 10
#     baseline: mean=0.9554 ± 0.0009
#     fs_set_intersection: mean=0.9261 ± 0.0512
#     fs_set_union: mean=0.9580 ± 0.0018
#     fs_set_weighted: mean=0.9581 ± 0.0010
#     op_set_intersection: mean=0.9569 ± 0.0034
#     op_set_union: mean=0.9588 ± 0.0018
#     op_set_weighted: mean=0.9578 ± 0.0015
#     x_set_intersection: mean=0.8984 ± 0.0493
#     x_set_union: mean=0.9569 ± 0.0012
#     x_set_weighted: mean=0.9520 ± 0.0014
#
#   Friedman: chi2=68.3202, p=0.0000 → SIGNIFICANT
#
#   Average ranks (lower = better):
#     baseline: 6.55
#     fs_set_intersection: 8.80
#     fs_set_union: 3.40
#     fs_set_weighted: 3.50
#     op_set_intersection: 4.30
#     op_set_union: 2.30
#     op_set_weighted: 3.55
#     x_set_intersection: 9.80
#     x_set_union: 4.60
#     x_set_weighted: 8.20
#
#   Nemenyi CD (alpha=0.05): 4.2841
#
#   Pairwise rank differences (showing only significant):
#     fs_set_intersection vs fs_set_union: |8.80 - 3.40| = 5.40 > 4.28 → fs_set_union is better
#     fs_set_intersection vs fs_set_weighted: |8.80 - 3.50| = 5.30 > 4.28 → fs_set_weighted is better
#     fs_set_intersection vs op_set_intersection: |8.80 - 4.30| = 4.50 > 4.28 → op_set_intersection is better
#     fs_set_intersection vs op_set_union: |8.80 - 2.30| = 6.50 > 4.28 → op_set_union is better
#     fs_set_intersection vs op_set_weighted: |8.80 - 3.55| = 5.25 > 4.28 → op_set_weighted is better
#     fs_set_union vs x_set_intersection: |3.40 - 9.80| = 6.40 > 4.28 → fs_set_union is better
#     fs_set_union vs x_set_weighted: |3.40 - 8.20| = 4.80 > 4.28 → fs_set_union is better
#     fs_set_weighted vs x_set_intersection: |3.50 - 9.80| = 6.30 > 4.28 → fs_set_weighted is better
#     fs_set_weighted vs x_set_weighted: |3.50 - 8.20| = 4.70 > 4.28 → fs_set_weighted is better
#     op_set_intersection vs x_set_intersection: |4.30 - 9.80| = 5.50 > 4.28 → op_set_intersection is better
#     op_set_union vs x_set_intersection: |2.30 - 9.80| = 7.50 > 4.28 → op_set_union is better
#     op_set_union vs x_set_weighted: |2.30 - 8.20| = 5.90 > 4.28 → op_set_union is better
#     op_set_weighted vs x_set_intersection: |3.55 - 9.80| = 6.25 > 4.28 → op_set_weighted is better
#     op_set_weighted vs x_set_weighted: |3.55 - 8.20| = 4.65 > 4.28 → op_set_weighted is better
#     x_set_intersection vs x_set_union: |9.80 - 4.60| = 5.20 > 4.28 → x_set_union is better
#
#     Total significant pairs: 15 / 45
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/significance_tests.csv
