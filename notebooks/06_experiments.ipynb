# %% [markdown]
# ### Run xai methods

# %%
from experiments.run_xai_fs import run_xai_fs
import pandas as pd
from src.utils.paths import COMPARISONS_DIR

# %%
DATASETS = ["ibtracs.last3years"]

# %%
all_results = []

for ds in DATASETS:
    results = run_xai_fs(ds)
    all_results.append(results)

# Combine results
combined = pd.concat(all_results, ignore_index=True)
combined.to_csv(COMPARISONS_DIR / "tables" / "xai_fs_all.csv", index=False)

print("\n" + "="*60)
print("ALL XAI FEATURE SELECTION COMPLETE")
print("="*60)
print(f"\nSHAP Results:")
print(combined[combined['method'] == 'shap'].groupby('n_features')['f1_score'].mean().to_string())
print(f"\nLIME Results:")
print(combined[combined['method'] == 'lime'].groupby('n_features')['f1_score'].mean().to_string())
# Out:
# ============================================================
# XAI-Based Feature Selection: ibtracs.last3years
# ============================================================
#
# Original features: 63
# Training samples: 18620
#
#
# ============================================================
# SHAP VALUES
# ============================================================
#
#
# --- Top 10 features ---
# Selected 10 features
#   logistic_regression  - F1: 0.8235, AUC: 0.9915
#   random_forest        - F1: 0.8370, AUC: 0.9919
#   xgboost              - F1: 0.8410, AUC: 0.9926
#
# --- Top 20 features ---
# Selected 20 features
#   logistic_regression  - F1: 0.7994, AUC: 0.9923
#   random_forest        - F1: 0.8393, AUC: 0.9912
#   xgboost              - F1: 0.8271, AUC: 0.9936
#
# --- Top 30 features ---
# Selected 30 features
#   logistic_regression  - F1: 0.8169, AUC: 0.9919
#   random_forest        - F1: 0.8459, AUC: 0.9921
#   xgboost              - F1: 0.8147, AUC: 0.9937
#
# --- Top 40 features ---
# Selected 40 features
#   logistic_regression  - F1: 0.8218, AUC: 0.9915
#   random_forest        - F1: 0.8352, AUC: 0.9913
#   xgboost              - F1: 0.8405, AUC: 0.9937
#
# --- Top 50 features ---
# Selected 50 features
#   logistic_regression  - F1: 0.8257, AUC: 0.9907
#   random_forest        - F1: 0.8314, AUC: 0.9879
#   xgboost              - F1: 0.8264, AUC: 0.9939
#
# ============================================================
# LIME (Local Interpretable Model-agnostic Explanations)
# ============================================================
#
#
# --- Top 10 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 10 features
#   logistic_regression  - F1: 0.8164, AUC: 0.9919
#   random_forest        - F1: 0.8023, AUC: 0.9807
#   xgboost              - F1: 0.8493, AUC: 0.9923
#
# --- Top 20 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 20 features
#   logistic_regression  - F1: 0.8045, AUC: 0.9916
#   random_forest        - F1: 0.8359, AUC: 0.9914
#   xgboost              - F1: 0.8161, AUC: 0.9922
#
# --- Top 30 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 30 features
#   logistic_regression  - F1: 0.7942, AUC: 0.9903
#   random_forest        - F1: 0.8427, AUC: 0.9916
#   xgboost              - F1: 0.8514, AUC: 0.9928
#
# --- Top 40 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 40 features
#   logistic_regression  - F1: 0.7911, AUC: 0.9907
#   random_forest        - F1: 0.8441, AUC: 0.9930
#   xgboost              - F1: 0.8382, AUC: 0.9941
#
# --- Top 50 features ---
#   Generating LIME explanations for 500 samples...
#     Progress: 0/500
#     Progress: 100/500
#     Progress: 200/500
#     Progress: 300/500
#     Progress: 400/500
# Selected 50 features
#   logistic_regression  - F1: 0.8067, AUC: 0.9892
#   random_forest        - F1: 0.8371, AUC: 0.9925
#   xgboost              - F1: 0.8294, AUC: 0.9938
#
# ============================================================
# ✓ XAI FS complete for ibtracs.last3years
# ✓ Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/comparisons/tables/xai_fs_ibtracs.last3years.csv
# ============================================================
#
#
# ============================================================
# ALL XAI FEATURE SELECTION COMPLETE
# ============================================================
#
# SHAP Results:
# n_features
# 10    0.833839
# 20    0.821920
# 30    0.825797
# 40    0.832519
# 50    0.827851
#
# LIME Results:
# n_features
# 10    0.822639
# 20    0.818819
# 30    0.829453
# 40    0.824494
# 50    0.824401
