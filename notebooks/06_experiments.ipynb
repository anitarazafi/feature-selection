# %% [markdown]
# ### Run xai methods

# %%
from experiments.run_xai_fs import run_xai_fs
import pandas as pd
from src.utils.paths import COMPARISONS_DIR

# %%
DATASETS = ["ibtracs.last3years"]
all_results = []
for ds in DATASETS:
    results = run_xai_fs(ds)
    all_results.append(results)

# Combine results
combined = pd.concat(all_results, ignore_index=True)
combined.to_csv(COMPARISONS_DIR / "tables" / "xai_fs_all.csv", index=False)

print("\n" + "="*60)
print("ALL XAI FEATURE SELECTION COMPLETE")
print("="*60)
print(f"\nSHAP Results:")
print(combined[combined['method'] == 'shap'].groupby('n_features')['f1_score'].mean().to_string())
print(f"\nLIME Results:")
print(combined[combined['method'] == 'lime'].groupby('n_features')['f1_score'].mean().to_string())
# Out:
# ============================================================
# XAI-Based Feature Selection: ibtracs.last3years
# ============================================================
#
# Training samples: 18620
#
# Test samples: 4655
# Original features: 61
#
#
# ============================================================
# SHAP VALUES
# ============================================================
#
#
# --- Top 10 features ---
# Selected 10 features
#   logistic_regression  - F1: 0.0435, AUC: 0.6538
#   random_forest        - F1: 0.3022, AUC: 0.8754
#   xgboost              - F1: 0.4494, AUC: 0.9052
#
# --- Top 20 features ---
# Selected 20 features
#   logistic_regression  - F1: 0.0561, AUC: 0.7112
#   random_forest        - F1: 0.2841, AUC: 0.9073
#   xgboost              - F1: 0.2733, AUC: 0.9053
#
# --- Top 30 features ---
# Selected 30 features
#   logistic_regression  - F1: 0.2118, AUC: 0.7586
#   random_forest        - F1: 0.2537, AUC: 0.9157
#   xgboost              - F1: 0.3807, AUC: 0.8860
#
# --- Top 40 features ---
# Selected 40 features
#   logistic_regression  - F1: 0.2286, AUC: 0.7926
#   random_forest        - F1: 0.2013, AUC: 0.9035
#   xgboost              - F1: 0.3422, AUC: 0.8639
#
# --- Top 50 features ---
# Selected 50 features
#   logistic_regression  - F1: 0.2527, AUC: 0.7938
#   random_forest        - F1: 0.2045, AUC: 0.9050
#   xgboost              - F1: 0.3452, AUC: 0.8826
#
# ============================================================
# LIME (Local Interpretable Model-agnostic Explanations)
# ============================================================
#
#
# --- Top 10 features ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 all_results = []
#       3 for ds in DATASETS:
# ----> 4     results = run_xai_fs(ds)
#       5     all_results.append(results)
#       7 # Combine results
#
# File ~/Desktop/masters/code/feature-selection/experiments/run_xai_fs.py:274, in run_xai_fs(dataset_name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/masters/code/feature-selection/experiments/run_xai_fs.py:83, in lime_feature_selection(X_train, X_test, y_train, top_k)
#      81 n_jobs = fs_config['common']['n_jobs']
#      82 # Train a model for LIME analysis
# ---> 83 model = RandomForestClassifier(n_estimators, random_state, n_jobs)
#      84 model.fit(X_train, y_train)
#      86 # Create LIME explainer
#
# TypeError: RandomForestClassifier.__init__() takes from 1 to 2 positional arguments but 4 were given
