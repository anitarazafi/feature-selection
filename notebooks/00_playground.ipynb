# %%
from src.visualization.plots import plot_feature_overlap
plot_feature_overlap("ibtracs.ALL.list.v04r01")
# Out:
# ── k=10 ──────────────────────────────────
#   Missing: differential_evolution_k10_features.json
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/feature_overlap_k10.png
#   Consensus features (all 6 methods): []
#   Majority features  (≥50% methods):              ['LON', 'BASIN_SI', 'USA_LON', 'BASIN_WP', 'LAT', 'BASIN_EP', 'BASIN_NI']
#
# ── k=30 ──────────────────────────────────
#   Missing: differential_evolution_k30_features.json
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/feature_overlap_k30.png
#   Consensus features (all 6 methods): ['LON', 'LAT', 'BASIN_NI']
#   Majority features  (≥50% methods):              ['USA_AGENCY_jtwc_wp', 'NATURE_NR', 'USA_AGENCY_hurdat_epa', 'USA_STATUS_nan', 'BASIN_WP', 'USA_LAT', 'USA_AGENCY_jtwc_io', 'BASIN_nan', 'WMO_AGENCY_bom', 'WMO_AGENCY_newdelhi', 'USA_LON', 'BASIN_SP', 'USA_AGENCY_nan', 'NATURE_TS', 'USA_WIND', 'USA_SSHS', 'BASIN_SI', 'WMO_AGENCY_hurdat_epa', 'BASIN_EP', 'USA_STATUS_TD', 'USA_AGENCY_jtwc_ep', 'USA_AGENCY_atcf', 'USA_STATUS_SD', 'WMO_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'WMO_PRES', 'USA_PRES', 'NUMBER', 'NATURE_ET', 'STORM_DIR', 'STORM_SPEED']
#
# ── k=50 ──────────────────────────────────
#   Missing: differential_evolution_k50_features.json
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/feature_overlap_k50.png
#   Consensus features (all 6 methods): ['LON', 'USA_AGENCY_hurdat_epa', 'BASIN_nan', 'WMO_AGENCY_nadi', 'WMO_AGENCY_hurdat_atl', 'WMO_AGENCY_reunion', 'USA_STATUS_HU', 'USA_AGENCY_hurdat_atl', 'LAT', 'NATURE_ET', 'NATURE_SS', 'BASIN_NI', 'NATURE_MX', 'USA_SSHS', 'STORM_DIR', 'NATURE_DS', 'WMO_AGENCY_hurdat_epa', 'USA_STATUS_DB', 'USA_PRES', 'BASIN_EP']
#   Majority features  (≥50% methods):              ['USA_AGENCY_jtwc_wp', 'USA_STATUS_LO', 'USA_STATUS_TY', 'NATURE_NR', 'USA_STATUS_XX', 'WMO_AGENCY_tokyo', 'USA_STATUS_SD', 'NUMBER', 'WMO_AGENCY_nan', 'USA_STATUS_nan', 'BASIN_WP', 'TRACK_TYPE_main', 'USA_LAT', 'USA_AGENCY_jtwc_io', 'WMO_AGENCY_bom', 'SEASON', 'WMO_AGENCY_newdelhi', 'USA_AGENCY_jtwc_sh', 'USA_LON', 'WMO_PRES', 'BASIN_SP', 'WMO_AGENCY_wellington', 'USA_AGENCY_nan', 'TRACK_TYPE_nan', 'NATURE_TS', 'USA_WIND', 'BASIN_SI', 'USA_STATUS_EX', 'USA_STATUS_TS', 'USA_STATUS_TD', 'USA_AGENCY_jtwc_ep', 'USA_STATUS_ST', 'USA_AGENCY_atcf', 'WMO_AGENCY_atcf', 'USA_AGENCY_jtwc_cp', 'USA_STATUS_SS', 'BASIN_SA', 'USA_AGENCY_cphc', 'STORM_SPEED']

# %%
from src.visualization.plots import plot_roc_curves
plot_roc_curves("ibtracs.ALL.list.v04r01")
# Out:
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/roc_curves.png
