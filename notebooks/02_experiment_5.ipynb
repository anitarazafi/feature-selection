# %%
from src.experiments.run_repeated_experiments import run_all_experiments

# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
combined_df, summary_df = run_all_experiments(ds)
print("\nDone! All repeated experiments complete.")
# Out:
# ############################################################
# # REPEATED EXPERIMENTS: 5 seeds
# # Seeds: [42, 123, 456, 789, 1024]
# # Dataset: ibtracs.ALL.list.v04r01
# ############################################################
#
#
# ************************************************************
# * RUN 1/5 — seed=42
# ************************************************************
#
# ...
# = Training baseline models for: ibtracs.ALL.list.v04r01 (seed=42)
# Training samples:   213577
# Validation samples: 30511
# Test samples:       61022
# Features: 63
#
# Training random_forest...
#   Training time: 1.97s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9266   0.9073
#   precision      0.8371   0.8878
#   recall         0.1069   0.1043
#   f1_score       0.1896   0.1866
#   auc            0.9390   0.9299
#
# Training xgboost...
#   Training time: 0.95s
#   Metric            Val     Test
#   ------------------------------
# ...
