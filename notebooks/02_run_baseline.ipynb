# %% [markdown]
# ### Run baseline, models without feature selection

# %%
from src.experiments.run_baseline import train_baseline

# %%
ds = "ibtracs.ALL.list.v04r01"
results = train_baseline(ds)

# %%
ds = "ibtracs.ALL.list.v04r01"
results = train_baseline(ds)
# Out:
# ============================================================
# =Training baseline models for: ibtracs.ALL.list.v04r01
# Training samples:   213577
# Validation samples: 30511
# Test samples:       61022
# Features: 63
#
# Training random_forest...
#   Training time: 2.05s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9266   0.9073
#   precision      0.8371   0.8878
#   recall         0.1069   0.1043
#   f1_score       0.1896   0.1866
#   auc            0.9390   0.9299
#
# Training xgboost...
#   Training time: 0.96s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9480   0.9366
#   precision      0.8473   0.8740
#   recall         0.4300   0.4422
#   f1_score       0.5705   0.5873
#   auc            0.9633   0.9547
#
# Training mlp...
#   Training time: 12.17s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9427   0.9276
#   precision      0.7807   0.8044
#   recall         0.3994   0.3838
#   f1_score       0.5285   0.5196
#   auc            0.9288   0.9089
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/baseline.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/models/baseline
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/plots/learning_curves.png

# %%
ds = "ibtracs.last3years"
results = train_baseline(ds)
# Out:
# ============================================================
# =Training baseline models for: ibtracs.last3years
# Training samples:   16292
# Validation samples: 2328
# Test samples:       4655
# Features: 53
#
# Training random_forest...
#   Training time: 0.21s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9356   0.9424
#   precision      1.0000   0.3333
#   recall         0.0066   0.0037
#   f1_score       0.0132   0.0074
#   auc            0.7753   0.8347
#
# Training xgboost...
#   Training time: 0.25s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.9343   0.9487
#   precision      0.4762   0.6321
#   recall         0.1325   0.2509
#   f1_score       0.2073   0.3592
#   auc            0.8531   0.8674
#
# Training mlp...
#   Training time: 1.92s
#   Metric            Val     Test
#   ------------------------------
#   accuracy       0.8419   0.8776
#   precision      0.1322   0.0938
#   recall         0.2583   0.1311
#   f1_score       0.1749   0.1094
#   auc            0.6076   0.7046
#
#
# Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/tables/baseline.csv
# Saved models to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/models/baseline
# Saved to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.last3years/plots/learning_curves.png
