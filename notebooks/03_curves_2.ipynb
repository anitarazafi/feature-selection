# %%
from src.analysis.best_results_2 import generate_comparison_table_2

# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
generate_comparison_table_2(ds)
# Out:
# Saved comparison table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/comparison_summary.tex
#
# Summary:
#   Baseline (63 feat.): F1=0.5897±0.0058, AUC=0.9554±0.0009
#   FS-Set (11--12 feat.): F1=0.6018±0.0104, AUC=0.9685±0.0015
#   Op-Set (10--12 feat.): F1=0.5994±0.0127, AUC=0.9687±0.0032
#   X-Set (11--13 feat.): F1=0.5855±0.0058, AUC=0.9707±0.0041
#
#   Best F1:  FS-Set
#   Best AUC: X-Set
# ...

# %%
from src.analysis.generate_friedman_table import generate_compact_significance_table

# %%
generate_compact_significance_table(ds)
# Out:
# Saved compact significance table to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/ibtracs.ALL.list.v04r01/tables/friedman_ranks.tex
#
# Nemenyi CD = 1.48 (pairs with rank difference > CD are significantly different)
#
# Average Ranks:
#   F1-score |      RF | Baseline=4.00, FS-Set=2.30, Op-Set=1.75, X-Set=1.95 | p=0.0003
#   F1-score | XGBoost | Baseline=2.60, FS-Set=1.70, Op-Set=2.10, X-Set=3.60 | p=0.0070
#   F1-score |     MLP | Baseline=2.70, FS-Set=3.20, Op-Set=3.00, X-Set=1.10 | p=0.0009
#    AUC-ROC |      RF | Baseline=4.00, FS-Set=2.20, Op-Set=2.20, X-Set=1.60 | p=0.0002
#    AUC-ROC | XGBoost | Baseline=3.50, FS-Set=1.65, Op-Set=2.15, X-Set=2.70 | p=0.0096
#    AUC-ROC |     MLP | Baseline=3.80, FS-Set=2.10, Op-Set=2.90, X-Set=1.20 | p=0.0001
# ...
