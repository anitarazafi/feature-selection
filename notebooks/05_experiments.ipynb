# %% [markdown]
# ### Run optimization methods

# %%
from experiments.run_optimization_fs import run_optimization_fs
import pandas as pd
from src.utils.paths import COMPARISONS_DIR

# %%
DATASETS = ["ibtracs.last3years"]

# %%
all_results = []

for ds in DATASETS:
    results = run_optimization_fs(ds)
    all_results.append(results)

# Combine results
combined = pd.concat(all_results, ignore_index=True)
combined.to_csv(COMPARISONS_DIR / "tables" / "optimization_fs_all.csv", index=False)

print("\n" + "="*60)
print("ALL OPTIMIZATION FEATURE SELECTION COMPLETE")
print("="*60)
print(f"\nPSO Results:")
print(combined[combined['method'] == 'pso'].groupby('n_features')['f1_score'].mean().to_string())
print(f"\nDifferential Evolution Results:")
print(combined[combined['method'] == 'differential_evolution'].groupby('n_features')['f1_score'].mean().to_string())
# Out:
# ============================================================
# Optimization-Based Feature Selection: ibtracs.last3years
# ============================================================
#
# Original features: 63
# Training samples: 18620
#
#
# ============================================================
# PARTICLE SWARM OPTIMIZATION (PSO)
# ============================================================
#
#
# --- Selecting 10 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.8945
#     Iteration 5: Best F1 = 0.9038
#     Iteration 10: Best F1 = 0.9071
#     Iteration 15: Best F1 = 0.9102
#     Final best F1: 0.9102
#   Selection completed in 103.17s
#   logistic_regression  - F1: 0.8262, AUC: 0.9936
#   random_forest        - F1: 0.8355, AUC: 0.9916
#   xgboost              - F1: 0.8282, AUC: 0.9934
#
# --- Selecting 20 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.8966
#     Iteration 5: Best F1 = 0.9042
#     Iteration 10: Best F1 = 0.9042
#     Iteration 15: Best F1 = 0.9047
#     Final best F1: 0.9056
#   Selection completed in 101.69s
#   logistic_regression  - F1: 0.8306, AUC: 0.9932
#   random_forest        - F1: 0.8375, AUC: 0.9943
#   xgboost              - F1: 0.8315, AUC: 0.9934
#
# --- Selecting 30 features ---
#   Running PSO: particles=30, iterations=20
#     Iteration 0: Best F1 = 0.8734
#     Iteration 5: Best F1 = 0.8935
#     Iteration 10: Best F1 = 0.8984
#     Iteration 15: Best F1 = 0.8984
#     Final best F1: 0.8984
#   Selection completed in 108.13s
#   logistic_regression  - F1: 0.7975, AUC: 0.9924
#   random_forest        - F1: 0.8213, AUC: 0.9898
#   xgboost              - F1: 0.8283, AUC: 0.9925
#
# ============================================================
# DIFFERENTIAL EVOLUTION (DE)
# ============================================================
#
#
# --- Selecting 10 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.8989
#     Generation 5: Best F1 = 0.8992
#     Generation 10: Best F1 = 0.9046
#     Generation 15: Best F1 = 0.9046
#     Final best F1: 0.9046
#   Selection completed in 102.22s
#   logistic_regression  - F1: 0.8190, AUC: 0.9933
#   random_forest        - F1: 0.8380, AUC: 0.9918
#   xgboost              - F1: 0.8227, AUC: 0.9933
#
# --- Selecting 20 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.8904
#     Generation 5: Best F1 = 0.8995
#     Generation 10: Best F1 = 0.8995
#     Generation 15: Best F1 = 0.8995
#     Final best F1: 0.8996
#   Selection completed in 112.52s
#   logistic_regression  - F1: 0.7873, AUC: 0.9928
#   random_forest        - F1: 0.8311, AUC: 0.9903
#   xgboost              - F1: 0.8399, AUC: 0.9933
#
# --- Selecting 30 features ---
#   Running DE: population=30, generations=20
#     Generation 0: Best F1 = 0.8775
#     Generation 5: Best F1 = 0.8867
#     Generation 10: Best F1 = 0.8910
#     Generation 15: Best F1 = 0.8931
#     Final best F1: 0.8931
#   Selection completed in 118.05s
#   logistic_regression  - F1: 0.8078, AUC: 0.9908
#   random_forest        - F1: 0.8387, AUC: 0.9935
#   xgboost              - F1: 0.8376, AUC: 0.9933
#
# ============================================================
# ✓ Optimization FS complete for ibtracs.last3years
# ✓ Saved results to /Users/anitarazafi/Desktop/masters/code/feature-selection/results/comparisons/tables/optimization_fs_ibtracs.last3years.csv
# ============================================================
#
#
# ============================================================
# ALL OPTIMIZATION FEATURE SELECTION COMPLETE
# ============================================================
#
# PSO Results:
# n_features
# 10    0.829976
# 20    0.833212
# 30    0.815706
#
# Differential Evolution Results:
# n_features
# 10    0.826577
# 20    0.819436
# 30    0.828055
