# %%
ds = "ibtracs.ALL.list.v04r01"

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="xgboost")
from src.experiments_new.sweep_k_traditional import sweep_k_traditional
results = sweep_k_traditional(ds)
# Out:
# ...
#  Validation Sweep: Choosing optimal k for Traditional FS
#  Dataset: ibtracs.ALL.list.v04r01, seed=42
# ...
# Total features: 63
# k values to sweep: [3, 5, 7, 10, 13, 15, 18, 20, 25, 30, 35, 40, 45, 50, 55, 60]
#
# Computing Mutual Information scores...
# MI scores computed.
#
# Pre-computing RFE rankings for all k values...
#   RFE k=  3 ... done
#   RFE k=  5 ... done
#   RFE k=  7 ... done
#   RFE k= 10 ... done
#   RFE k= 13 ... done
#   RFE k= 15 ... done
#   RFE k= 18 ... done
#   RFE k= 20 ... done
#   RFE k= 25 ... done
#   RFE k= 30 ... done
#   RFE k= 35 ... done
#   RFE k= 40 ... done
#   RFE k= 45 ... done
#   RFE k= 50 ... done
#   RFE k= 55 ... done
#   RFE k= 60 ... done
#
#   k=  3 ... MI: AUC=0.8616 F1=0.0709  |  RFE: AUC=0.9842 F1=0.7622  |  Avg: AUC=0.9229 F1=0.4166
#   k=  5 ... MI: AUC=0.8958 F1=0.2866  |  RFE: AUC=0.9834 F1=0.7582  |  Avg: AUC=0.9396 F1=0.5224
#   k=  7 ... MI: AUC=0.9838 F1=0.7656  |  RFE: AUC=0.9818 F1=0.7452  |  Avg: AUC=0.9828 F1=0.7554
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="xgboost")
from src.experiments_new.sweep_k_optimization import sweep_k_optimization
results = sweep_k_optimization(ds)
# Out:
# ...
#  Validation Sweep: Choosing optimal k for Optimization FS
#  Dataset: ibtracs.ALL.list.v04r01, seed=42
# ...
# Total features: 63
# k values to sweep: [3, 5, 7, 10, 13, 15, 18, 20, 25, 30]
#
#
#   k=  3
#     Running PSO (k=3)... 126.9s
#     Running DE  (k=3)... 281.9s
#     PSO: AUC=0.9601 F1=0.5682  |  DE: AUC=0.9842 F1=0.7659  |  Avg: AUC=0.9721 F1=0.6671
#
#   k=  5
#     Running PSO (k=5)... 134.3s
#     Running DE  (k=5)... 313.6s
#     PSO: AUC=0.9843 F1=0.7607  |  DE: AUC=0.9846 F1=0.7759  |  Avg: AUC=0.9844 F1=0.7683
#
#   k=  7
#     Running PSO (k=7)... 145.2s
#     Running DE  (k=7)... 335.8s
#     PSO: AUC=0.9834 F1=0.7631  |  DE: AUC=0.9849 F1=0.7794  |  Avg: AUC=0.9841 F1=0.7713
#
#   k= 10
#     Running PSO (k=10)... 162.4s
#     Running DE  (k=10)... 379.9s
#     PSO: AUC=0.9840 F1=0.7648  |  DE: AUC=0.9844 F1=0.7800  |  Avg: AUC=0.9842 F1=0.7724
#
#   k= 13
#     Running PSO (k=13)... 173.4s
#     Running DE  (k=13)... 388.8s
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="xgboost")
from src.experiments_new.sweep_k_xai import sweep_k_xai
results = sweep_k_xai(ds)
# Out:
# ...
#  Validation Sweep: Choosing optimal k for XAI FS
#  Dataset: ibtracs.ALL.list.v04r01, seed=42
# ...
# Total features: 63
# k values to sweep: [3, 5, 7, 10, 13, 15, 18, 20, 25, 30, 35, 40, 45, 50, 55, 60]
#
# Pre-training XGBoost explainer model...
# Explainer model trained.
#
# Computing SHAP feature rankings...
#  99%|===================| 9874/10000 [00:25<00:00]
# SHAP ranking computed in 25.0s
#
# Computing LIME feature rankings...
#     Computing LIME explanations (500 samples)...
#       LIME progress: 100/500
#       LIME progress: 200/500
#       LIME progress: 300/500
#       LIME progress: 400/500
# LIME ranking computed in 15.9s
#
#   k=  3 ... SHAP: AUC=0.9842 F1=0.7622  |  LIME: AUC=0.4995 F1=0.0000  |  Avg: AUC=0.7418 F1=0.3811
#   k=  5 ... SHAP: AUC=0.9839 F1=0.7680  |  LIME: AUC=0.4988 F1=0.0000  |  Avg: AUC=0.7413 F1=0.3840
#   k=  7 ... SHAP: AUC=0.9824 F1=0.7581  |  LIME: AUC=0.6712 F1=0.0000  |  Avg: AUC=0.8268 F1=0.3791
# ...
